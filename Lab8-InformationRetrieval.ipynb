# %%
pip install num2words
# Out:
# Requirement already satisfied: num2words in c:\users\hp\anaconda3\lib\site-packages (0.5.10)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\hp\anaconda3\lib\site-packages (from num2words) (0.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk #need for dealing with text 
import os   # need for looping through folders 
import string 
import numpy as np 
import copy 
import pandas as pd 
import pickle 
import re 
import math # need for computing TF-IDF score

# %%
from nltk.corpus import stopwords  
from nltk.tokenize import word_tokenize  
from nltk.stem import PorterStemmer  
from collections import Counter 
from num2words import num2words

# %%
title = "comp.graphics"

os.chdir("C:/20_newsgroups")

path = []
for(dirpath, dirnames, filenames) in os.walk(str(os.getcwd())+"/"+title+"/"):
    for i in filenames:
        path.append(str(dirpath)+str("/")+i)

# %%
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words:
            new_text = new_text + " " + w
    return np.char.strip(new_text)

                       
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, " ", " ")
    data = np.char.replace(data, ',', '')
    return data 

def convert_lower_case(data):
    return np.char.lower(data)


def stemming(data):
    stemmer= PorterStemmer()

    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return np.char.strip(new_text) 

 
def convert_numbers(data):
    data = np.char.replace(data, "0", " zero ")
    data = np.char.replace(data, "1", " one ")
    data = np.char.replace(data, "2", " two ")
    data = np.char.replace(data, "3", " three ")
    data = np.char.replace(data, "4", " four ")
    data = np.char.replace(data, "5", " five ")
    data = np.char.replace(data, "6", " six ")
    data = np.char.replace(data, "7", " seven ")
    data = np.char.replace(data, "8", " eight ")
    data = np.char.replace(data, "9", " nine ")
    return data 

 
def remove_header(data):
    try:
        ind = data.index('\n\n')
        data = data[ind:]
    except:
        print("No Header")
    return data 


def remove_apostrophe(data):
    return np.char.replace(data, "'", "") 

def remove_single_characters(data):
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if len(w) > 1:
            new_text = new_text + " " + w
    return np.char.strip(new_text)

# %%
def preprocess(data, query):
    data = remove_header(data) 
    data = convert_lower_case(data)
    data = convert_numbers(data)
    data = remove_punctuation(data)
    data = remove_stop_words(data)
    data = remove_apostrophe(data)
    data = remove_single_characters(data)
    data = stemming(data) 
    return data

# %%
for i in range(len(filenames)):
    print(dirpath+'/'+filenames[i])
# Out:
# C:\20_newsgroups/comp.graphics//37261
# C:\20_newsgroups/comp.graphics//37913
# C:\20_newsgroups/comp.graphics//37914
# C:\20_newsgroups/comp.graphics//37915
# C:\20_newsgroups/comp.graphics//37916
# C:\20_newsgroups/comp.graphics//37917
# C:\20_newsgroups/comp.graphics//37918
# C:\20_newsgroups/comp.graphics//37919
# C:\20_newsgroups/comp.graphics//37920
# C:\20_newsgroups/comp.graphics//37921
# C:\20_newsgroups/comp.graphics//37922
# C:\20_newsgroups/comp.graphics//37923
# C:\20_newsgroups/comp.graphics//37924
# C:\20_newsgroups/comp.graphics//37925
# C:\20_newsgroups/comp.graphics//37926
# C:\20_newsgroups/comp.graphics//37927
# C:\20_newsgroups/comp.graphics//37928
# C:\20_newsgroups/comp.graphics//37929
# C:\20_newsgroups/comp.graphics//37930
# C:\20_newsgroups/comp.graphics//37931
# C:\20_newsgroups/comp.graphics//37932
# C:\20_newsgroups/comp.graphics//37933
# C:\20_newsgroups/comp.graphics//37934
# C:\20_newsgroups/comp.graphics//37935
# C:\20_newsgroups/comp.graphics//37936
# C:\20_newsgroups/comp.graphics//37937
# C:\20_newsgroups/comp.graphics//37938
# C:\20_newsgroups/comp.graphics//37939
# C:\20_newsgroups/comp.graphics//37940
# C:\20_newsgroups/comp.graphics//37941
# C:\20_newsgroups/comp.graphics//37942
# C:\20_newsgroups/comp.graphics//37943
# C:\20_newsgroups/comp.graphics//37944
# C:\20_newsgroups/comp.graphics//37945
# C:\20_newsgroups/comp.graphics//37946
# C:\20_newsgroups/comp.graphics//37947
# C:\20_newsgroups/comp.graphics//37948
# C:\20_newsgroups/comp.graphics//37949
# C:\20_newsgroups/comp.graphics//37950
# C:\20_newsgroups/comp.graphics//37951
# C:\20_newsgroups/comp.graphics//37952
# C:\20_newsgroups/comp.graphics//37953
# C:\20_newsgroups/comp.graphics//37954
# C:\20_newsgroups/comp.graphics//37955
# C:\20_newsgroups/comp.graphics//37956
# C:\20_newsgroups/comp.graphics//37957
# C:\20_newsgroups/comp.graphics//37958
# C:\20_newsgroups/comp.graphics//37959
# C:\20_newsgroups/comp.graphics//37960
# C:\20_newsgroups/comp.graphics//37961
# C:\20_newsgroups/comp.graphics//37962
# C:\20_newsgroups/comp.graphics//37963
# C:\20_newsgroups/comp.graphics//38099
# C:\20_newsgroups/comp.graphics//38214
# C:\20_newsgroups/comp.graphics//38215
# C:\20_newsgroups/comp.graphics//38216
# C:\20_newsgroups/comp.graphics//38217
# C:\20_newsgroups/comp.graphics//38218
# C:\20_newsgroups/comp.graphics//38219
# C:\20_newsgroups/comp.graphics//38220
# C:\20_newsgroups/comp.graphics//38221
# C:\20_newsgroups/comp.graphics//38222
# C:\20_newsgroups/comp.graphics//38223
# C:\20_newsgroups/comp.graphics//38224
# C:\20_newsgroups/comp.graphics//38225
# C:\20_newsgroups/comp.graphics//38226
# C:\20_newsgroups/comp.graphics//38227
# C:\20_newsgroups/comp.graphics//38228
# C:\20_newsgroups/comp.graphics//38229
# C:\20_newsgroups/comp.graphics//38230
# C:\20_newsgroups/comp.graphics//38231
# C:\20_newsgroups/comp.graphics//38232
# C:\20_newsgroups/comp.graphics//38233
# C:\20_newsgroups/comp.graphics//38234
# C:\20_newsgroups/comp.graphics//38235
# C:\20_newsgroups/comp.graphics//38236
# C:\20_newsgroups/comp.graphics//38237
# C:\20_newsgroups/comp.graphics//38238
# C:\20_newsgroups/comp.graphics//38239
# C:\20_newsgroups/comp.graphics//38240
# C:\20_newsgroups/comp.graphics//38241
# C:\20_newsgroups/comp.graphics//38242
# C:\20_newsgroups/comp.graphics//38243
# C:\20_newsgroups/comp.graphics//38244
# C:\20_newsgroups/comp.graphics//38245
# C:\20_newsgroups/comp.graphics//38246
# C:\20_newsgroups/comp.graphics//38247
# C:\20_newsgroups/comp.graphics//38248
# C:\20_newsgroups/comp.graphics//38249
# C:\20_newsgroups/comp.graphics//38250
# C:\20_newsgroups/comp.graphics//38251
# C:\20_newsgroups/comp.graphics//38252
# C:\20_newsgroups/comp.graphics//38253
# C:\20_newsgroups/comp.graphics//38254
# C:\20_newsgroups/comp.graphics//38255
# C:\20_newsgroups/comp.graphics//38256
# C:\20_newsgroups/comp.graphics//38257
# C:\20_newsgroups/comp.graphics//38258
# C:\20_newsgroups/comp.graphics//38259
# C:\20_newsgroups/comp.graphics//38260

# %%
def print_doc(id):
    file = open(dirpath+'/'+ filenames[id], 'r', encoding = 'cp1250')
    text = file.read().strip()
    file.close()
    
    processed_text.append(word_tokenize(str(preprocess(text)))) 
    print(processed_text)

# %%
processed_text = []
for i in range(len(filenames)):
    file = open(dirpath+'/'+filenames[i], 'r' ,encoding = 'cp1250' , errors='ignore')
    text = file.read().strip()
    file.close()
    processed_text.append(word_tokenize(str(preprocess(text,True))))

processed_text
# Out:
# No Header
# No Header
# [['call',
#   'present',
#   'navi',
#   'scientif',
#   'visual',
#   'virtual',
#   'realiti',
#   'seminar',
#   'tuesday',
#   'june',
#   'two',
#   'two',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'carderock',
#   'divis',
#   'naval',
#   'surfac',
#   'warfar',
#   'center',
#   'formerli',
#   'david',
#   'taylor',
#   'research',
#   'center',
#   'bethesda',
#   'maryland',
#   'sponsor',
#   'ness',
#   'navi',
#   'engin',
#   'softwar',
#   'system',
#   'sponsor',
#   'one',
#   'day',
#   'navi',
#   'scientif',
#   'visual',
#   'virtual',
#   'realiti',
#   'seminar',
#   'purpos',
#   'seminar',
#   'present',
#   'exchang',
#   'inform',
#   'navi',
#   'relat',
#   'scientif',
#   'visual',
#   'virtual',
#   'realiti',
#   'program',
#   'research',
#   'develop',
#   'applic',
#   'present',
#   'present',
#   'solicit',
#   'aspect',
#   'navi',
#   'relat',
#   'scientif',
#   'visual',
#   'virtual',
#   'realiti',
#   'current',
#   'work',
#   'work',
#   'progress',
#   'propos',
#   'work',
#   'navi',
#   'organ',
#   'consid',
#   'four',
#   'type',
#   'present',
#   'avail',
#   'one',
#   'regular',
#   'present',
#   'two',
#   'zero',
#   'three',
#   'zero',
#   'minut',
#   'length',
#   'two',
#   'short',
#   'present',
#   'one',
#   'zero',
#   'minut',
#   'length',
#   'three',
#   'video',
#   'present',
#   'stand',
#   'alon',
#   'videotap',
#   'author',
#   'need',
#   'attend',
#   'seminar',
#   'four',
#   'scientif',
#   'visual',
#   'virtual',
#   'realiti',
#   'demonstr',
#   'byoh',
#   'accept',
#   'present',
#   'publish',
#   'proceed',
#   'howev',
#   'viewgraph',
#   'materi',
#   'reproduc',
#   'seminar',
#   'attende',
#   'abstract',
#   'author',
#   'submit',
#   'one',
#   'page',
#   'abstract',
#   'videotap',
#   'robert',
#   'lipman',
#   'naval',
#   'surfac',
#   'warfar',
#   'center',
#   'carderock',
#   'divis',
#   'code',
#   'two',
#   'zero',
#   'four',
#   'two',
#   'bethesda',
#   'maryland',
#   'two',
#   'zero',
#   'zero',
#   'eight',
#   'four',
#   'five',
#   'zero',
#   'zero',
#   'zero',
#   'voic',
#   'three',
#   'zero',
#   'one',
#   'two',
#   'two',
#   'seven',
#   'three',
#   'six',
#   'one',
#   'eight',
#   'fax',
#   'three',
#   'zero',
#   'one',
#   'two',
#   'two',
#   'seven',
#   'five',
#   'seven',
#   'five',
#   'three',
#   'mail',
#   'lipman',
#   'oasi',
#   'dt',
#   'navi',
#   'mil',
#   'author',
#   'includ',
#   'type',
#   'present',
#   'affili',
#   'address',
#   'telephon',
#   'fax',
#   'number',
#   'address',
#   'multi',
#   'author',
#   'paper',
#   'design',
#   'one',
#   'point',
#   'contact',
#   'deadlin',
#   'abstact',
#   'submiss',
#   'deadlin',
#   'april',
#   'three',
#   'zero',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'notif',
#   'accept',
#   'sent',
#   'may',
#   'one',
#   'four',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'materi',
#   'reproduct',
#   'must',
#   'receiv',
#   'june',
#   'one',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'inform',
#   'contact',
#   'robert',
#   'lipman',
#   'address',
#   'pleas',
#   'distribut',
#   'wide',
#   'possibl',
#   'thank',
#   'robert',
#   'lipman',
#   'internet',
#   'lipman',
#   'oasi',
#   'dt',
#   'navi',
#   'mil',
#   'david',
#   'taylor',
#   'model',
#   'basin',
#   'cdnswc',
#   'lip',
#   'ocean',
#   'dt',
#   'navi',
#   'mil',
#   'comput',
#   'signatur',
#   'voicenet',
#   'three',
#   'zero',
#   'one',
#   'two',
#   'two',
#   'seven',
#   'three',
#   'six',
#   'one',
#   'eight',
#   'structur',
#   'group',
#   'code',
#   'two',
#   'zero',
#   'four',
#   'two',
#   'factsnet',
#   'three',
#   'zero',
#   'one',
#   'two',
#   'two',
#   'seven',
#   'five',
#   'seven',
#   'five',
#   'three',
#   'bethesda',
#   'maryland',
#   'two',
#   'zero',
#   'zero',
#   'eight',
#   'four',
#   'five',
#   'zero',
#   'zero',
#   'zero',
#   'phishnet',
#   'stock',
#   'long',
#   'leg',
#   'sixth',
#   'sick',
#   'shiek',
#   'sixth',
#   'sheep',
#   'sick'],
#  ['gnuplot',
#   'etc',
#   'make',
#   'easi',
#   'plot',
#   'real',
#   'valu',
#   'function',
#   'two',
#   'variabl',
#   'want',
#   'plot',
#   'function',
#   'whose',
#   'valu',
#   'two',
#   'vector',
#   'plot',
#   'array',
#   'arrow',
#   'complet',
#   'arrowhead',
#   'go',
#   'thought',
#   'would',
#   'ask',
#   'whether',
#   'someon',
#   'alreadi',
#   'done',
#   'work',
#   'pointer',
#   'thanx',
#   'advanc',
#   'tom',
#   'weston',
#   'usenet',
#   'weston',
#   'ucssun',
#   'one',
#   'sdsu',
#   'edu',
#   'depart',
#   'philosophi',
#   'six',
#   'one',
#   'nine',
#   'five',
#   'nine',
#   'four',
#   'six',
#   'two',
#   'one',
#   'eight',
#   'offic',
#   'san',
#   'diego',
#   'state',
#   'univ',
#   'six',
#   'one',
#   'nine',
#   'five',
#   'seven',
#   'five',
#   'seven',
#   'four',
#   'seven',
#   'seven',
#   'home',
#   'san',
#   'diego',
#   'ca',
#   'nine',
#   'two',
#   'one',
#   'eight',
#   'two',
#   'zero',
#   'three',
#   'zero',
#   'three'],
#  ['articl',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'apr',
#   'three',
#   'one',
#   'eight',
#   'three',
#   'three',
#   'zero',
#   'three',
#   'six',
#   'four',
#   'four',
#   'two',
#   'usl',
#   'edu',
#   'jna',
#   'eight',
#   'one',
#   'eight',
#   'two',
#   'uc',
#   'usl',
#   'edu',
#   'armstrong',
#   'jay',
#   'write',
#   'someon',
#   'pleas',
#   'tell',
#   'ftp',
#   'dta',
#   'dmorph',
#   'dmorf',
#   'dave',
#   'morph',
#   'think',
#   'mean',
#   'dtax',
#   'dave',
#   'tga',
#   'assembl',
#   'avail',
#   'msdo',
#   'upload',
#   'directori',
#   'wuarchiv',
#   'arj',
#   'bundl',
#   'respect',
#   'xmemori',
#   'version',
#   'dmorfx',
#   'exe',
#   'dtax',
#   'exe',
#   'also',
#   'find',
#   'version',
#   'aaplay',
#   'exe',
#   'view',
#   'file',
#   'creat',
#   'dta',
#   'exe',
#   'dtax',
#   'exe',
#   'download',
#   'whole',
#   'bunch',
#   'last',
#   'week',
#   'morph',
#   'away',
#   'afternoon',
#   'sinc',
#   'programm',
#   'bit',
#   'buggi',
#   'definit',
#   'readi',
#   'spread',
#   'mass',
#   'well',
#   'written',
#   'interfac',
#   'frustrat',
#   'first',
#   'get',
#   'easi',
#   'figur',
#   'trick',
#   'notic',
#   'dmorfx',
#   'crash',
#   'horribl',
#   'tri',
#   'morph',
#   'without',
#   'use',
#   'spline',
#   'option',
#   'sure',
#   'sinc',
#   'nt',
#   'sourc',
#   'think',
#   'written',
#   'tp',
#   'six',
#   'zero',
#   'anyon',
#   'els',
#   'come',
#   'hint',
#   'get',
#   'thing',
#   'work',
#   'right',
#   'tell',
#   'took',
#   'sever',
#   'hour',
#   'first',
#   'time',
#   'figur',
#   'use',
#   'durn',
#   'spline',
#   'would',
#   'work',
#   'jna',
#   'jna',
#   'eight',
#   'one',
#   'eight',
#   'two',
#   'usl',
#   'edu',
#   'ryan',
#   'rap',
#   'ci',
#   'ufl',
#   'edu'],
#  ['hello',
#   'look',
#   'add',
#   'voic',
#   'input',
#   'capabl',
#   'user',
#   'interfac',
#   'develop',
#   'hp',
#   'seven',
#   'three',
#   'zero',
#   'unix',
#   'workstat',
#   'would',
#   'greatli',
#   'appreci',
#   'inform',
#   'anyon',
#   'would',
#   'care',
#   'offer',
#   'voic',
#   'input',
#   'system',
#   'easili',
#   'access',
#   'unix',
#   'environ',
#   'name',
#   'adress',
#   'applic',
#   'vendor',
#   'well',
#   'experi',
#   'specif',
#   'system',
#   'would',
#   'help',
#   'pleas',
#   'respond',
#   'via',
#   'email',
#   'post',
#   'summari',
#   'suffici',
#   'interest',
#   'thank',
#   'ken',
#   'found',
#   'sever',
#   'impress',
#   'system',
#   'ibm',
#   'pc',
#   'would',
#   'like',
#   'avoid',
#   'hassl',
#   'purchas',
#   'maintain',
#   'separ',
#   'pc',
#   'possibl',
#   'ken',
#   'hinckley',
#   'kph',
#   'two',
#   'virginia',
#   'edu',
#   'univers',
#   'virginia',
#   'neurosurg',
#   'visual',
#   'laboratori'],
#  ['recent',
#   'got',
#   'file',
#   'describ',
#   'librari',
#   'render',
#   'routin',
#   'call',
#   'sipp',
#   'simpl',
#   'polygon',
#   'processor',
#   'could',
#   'anyon',
#   'tell',
#   'ftp',
#   'sourc',
#   'code',
#   'newest',
#   'version',
#   'around',
#   'also',
#   've',
#   'never',
#   'use',
#   'renderman',
#   'wonder',
#   'renderman',
#   'like',
#   'sipp',
#   'ie',
#   'librari',
#   'render',
#   'routin',
#   'one',
#   'use',
#   'make',
#   'program',
#   'creat',
#   'imag',
#   'thank',
#   'joe',
#   'tham',
#   'joe',
#   'tham',
#   'joth',
#   'ersi',
#   'edmonton',
#   'ab',
#   'ca'],
#  ['nine',
#   'hh',
#   'dtek',
#   'chalmer',
#   'se',
#   'henrik',
#   'harmsen',
#   'write',
#   'one',
#   'four',
#   'bit',
#   'per',
#   'give',
#   'horribl',
#   'machband',
#   'visibl',
#   'almost',
#   'pictur',
#   'five',
#   'bit',
#   'per',
#   'three',
#   'two',
#   'seven',
#   'six',
#   'eight',
#   'six',
#   'five',
#   'zero',
#   'zero',
#   'zero',
#   'color',
#   'give',
#   'visibl',
#   'machband',
#   'color',
#   'gradient',
#   'pictur',
#   'almost',
#   'machband',
#   'color',
#   'resolut',
#   'see',
#   'small',
#   'machband',
#   'smooth',
#   'color',
#   'gradient',
#   'pictur',
#   'situiat',
#   'get',
#   'visibl',
#   'mach',
#   'band',
#   'even',
#   'two',
#   'four',
#   'bit',
#   'card',
#   'creat',
#   'smooth',
#   'color',
#   'gradient',
#   'dark',
#   'green',
#   'white',
#   'yellow',
#   'someth',
#   'turn',
#   'contrast',
#   'monitor',
#   'probabl',
#   'see',
#   'mach',
#   'band',
#   'nt',
#   'mean',
#   'damn',
#   'henrik',
#   'attempt',
#   'help',
#   'use',
#   'common',
#   'misconcept',
#   'correct',
#   'mach',
#   'band',
#   'occur',
#   'imag',
#   'color',
#   'quantiz',
#   'see',
#   'nt',
#   'enough',
#   'bit',
#   'human',
#   'eye',
#   'respons',
#   'transit',
#   'edg',
#   'intens',
#   'result',
#   'color',
#   'near',
#   'transist',
#   'look',
#   'brighter',
#   'brighter',
#   'side',
#   'darker',
#   'darker',
#   'side',
#   'andr',
#   'andr',
#   'yew',
#   'andrey',
#   'cco',
#   'caltech',
#   'edu',
#   'one',
#   'three',
#   'one',
#   'two',
#   'one',
#   'five',
#   'one',
#   'three',
#   'nine',
#   'two'],
#  ['mac',
#   'user',
#   'come',
#   'graphic',
#   'softwar',
#   'hardwar',
#   've',
#   'recent',
#   'come',
#   'across',
#   'larg',
#   'number',
#   'tttddd',
#   'format',
#   'model',
#   'databas',
#   'softwar',
#   'mac',
#   'unix',
#   'translat',
#   'someth',
#   'could',
#   'use',
#   'like',
#   'dxf',
#   'pleas',
#   'repli',
#   'via',
#   'email',
#   'thanx',
#   'eric',
#   'oehler',
#   'oehler',
#   'picard',
#   'cs',
#   'wisc',
#   'edu'],
#  ['look',
#   'public',
#   'access',
#   'sourc',
#   'data',
#   'depict',
#   'brain',
#   'neuron',
#   'function',
#   'especi',
#   'interest',
#   'would',
#   'volumetr',
#   'data',
#   'brain',
#   'scan',
#   'electromicograph',
#   'forth',
#   'pleas',
#   'email',
#   'let',
#   'know',
#   'know',
#   'humbio',
#   'project',
#   'cd',
#   'rom',
#   'base',
#   'curriculum',
#   'tool',
#   'sixth',
#   'seventh',
#   'eigth',
#   'grader',
#   'studi',
#   'function',
#   'human',
#   'brain',
#   'effect',
#   'neurotransmitt',
#   'alcohol',
#   'drug',
#   'special',
#   'focu',
#   'depict',
#   'effect',
#   'neurotransmitt',
#   'behavior',
#   'volotta',
#   'interact',
#   'video',
#   'produc',
#   'project',
#   'stanford',
#   'univ',
#   'iti',
#   'current',
#   'pre',
#   'product',
#   'phase',
#   'look',
#   'data',
#   'set',
#   'visual',
#   'depict',
#   'brain',
#   'function',
#   'whole',
#   'brain',
#   'neuron',
#   'molecular',
#   'level',
#   'intend',
#   'use',
#   'state',
#   'art',
#   'visual',
#   'tool',
#   'render',
#   'instruct',
#   'visual',
#   'two',
#   'three',
#   'four',
#   'dimension',
#   'data',
#   'set',
#   'well',
#   'use',
#   'alreadi',
#   'complet',
#   'visual',
#   'best',
#   'effect'],
#  ['humbio',
#   'project',
#   'call',
#   'data',
#   'visual',
#   'humbio',
#   'project',
#   'cd',
#   'rom',
#   'base',
#   'curriculum',
#   'tool',
#   'sixth',
#   'seventh',
#   'eigth',
#   'grader',
#   'studi',
#   'function',
#   'human',
#   'brain',
#   'effect',
#   'neurotransmitt',
#   'alcohol',
#   'drug',
#   'special',
#   'focu',
#   'depict',
#   'effect',
#   'neurotransmitt',
#   'behavior',
#   'volotta',
#   'interact',
#   'video',
#   'produc',
#   'project',
#   'stanford',
#   'univers',
#   'current',
#   'pre',
#   'product',
#   'phase',
#   'look',
#   'data',
#   'set',
#   'visual',
#   'depict',
#   'brain',
#   'function',
#   'whole',
#   'brain',
#   'neuron',
#   'molecular',
#   'level',
#   'intend',
#   'use',
#   'state',
#   'art',
#   'visual',
#   'tool',
#   'render',
#   'instruct',
#   'visual',
#   'two',
#   'three',
#   'four',
#   'dimension',
#   'data',
#   'set',
#   'well',
#   'use',
#   'alreadi',
#   'complet',
#   'visual',
#   'best',
#   'effect',
#   're',
#   'interest',
#   'share',
#   'data',
#   'purpos',
#   'educ',
#   'support',
#   'introduct',
#   'cd',
#   'rom',
#   'scientif',
#   'visual',
#   'technolog',
#   'school',
#   'pleas',
#   'mail',
#   'phugh',
#   'igc',
#   'org',
#   'includ',
#   'name',
#   'organ',
#   'type',
#   'format',
#   'data',
#   'might',
#   'will',
#   'provid',
#   'eager',
#   'begin',
#   'product',
#   'next',
#   'month',
#   'excit',
#   'hear',
#   'sincer',
#   'peter',
#   'hugh',
#   'humbio',
#   'project',
#   'humbio',
#   'project',
#   'way',
#   'affili',
#   'appl',
#   'comput',
#   'igc'],
#  ['hello',
#   'everybodi',
#   'use',
#   'pixar',
#   'renderman',
#   'three',
#   'scene',
#   'descript',
#   'languag',
#   'creat',
#   'three',
#   'world',
#   'pleas',
#   'help',
#   'use',
#   'renderman',
#   'librari',
#   'next',
#   'document',
#   'nextstep',
#   'version',
#   'renderman',
#   'avail',
#   'creat',
#   'complic',
#   'scene',
#   'render',
#   'use',
#   'surfac',
#   'shader',
#   'bring',
#   'life',
#   'appli',
#   'shadow',
#   'reflect',
#   'far',
#   'understand',
#   'defin',
#   'environment',
#   'shadow',
#   'map',
#   'produc',
#   'reflect',
#   'shadow',
#   'know',
#   'use',
#   'advis',
#   'simpl',
#   'rib',
#   'exampl',
#   'appreci',
#   'thank',
#   'advanc',
#   'alex',
#   'kolesov',
#   'moscow',
#   'russia',
#   'talu',
#   'imag',
#   'commun',
#   'corpor',
#   'mail',
#   'alex',
#   'talu',
#   'msk',
#   'su',
#   'next',
#   'mail',
#   'accept'],
#  ['articl',
#   'one',
#   'pp',
#   'nine',
#   'nine',
#   'one',
#   'six',
#   'three',
#   'cc',
#   'tut',
#   'fi',
#   'jk',
#   'eight',
#   'seven',
#   'three',
#   'seven',
#   'seven',
#   'lehtori',
#   'cc',
#   'tut',
#   'fi',
#   'kouhia',
#   'juhana',
#   'write',
#   'articl',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'apr',
#   'five',
#   'zero',
#   'four',
#   'zero',
#   'eight',
#   'one',
#   'nine',
#   'one',
#   'four',
#   'nine',
#   'four',
#   'three',
#   'kpc',
#   'com',
#   'hollasch',
#   'kpc',
#   'com',
#   'steve',
#   'hollasch',
#   'write',
#   'think',
#   're',
#   'propos',
#   'would',
#   'work',
#   'get',
#   'extra',
#   'one',
#   'mayb',
#   'two',
#   'extra',
#   'bit',
#   'color',
#   'resolut',
#   'howev',
#   'display',
#   'chould',
#   'zero',
#   'full',
#   'intens',
#   'primari',
#   'nt',
#   'think',
#   'get',
#   'great',
#   'equival',
#   'two',
#   'four',
#   'bit',
#   'photograph',
#   'suggest',
#   'wrote',
#   'problem',
#   'problem',
#   'clearli',
#   'visibl',
#   'seven',
#   'bit',
#   'imag',
#   'mention',
#   'two',
#   'four',
#   'bit',
#   'imag',
#   'descript',
#   'experi',
#   'delet',
#   'one',
#   'bit',
#   'imag',
#   'view',
#   'quickli',
#   'sync',
#   'screen',
#   'one',
#   'zero',
#   'zero',
#   'intens',
#   'could',
#   'better',
#   'dunno',
#   'delet',
#   'case',
#   'get',
#   'black',
#   'color',
#   'slow',
#   'machin',
#   'problem',
#   'could',
#   'tri',
#   'eight',
#   'bit',
#   'screen',
#   'nt',
#   'know',
#   'render',
#   'pixel',
#   'constant',
#   'time',
#   'recal',
#   'doubl',
#   'buffer',
#   'imag',
#   'color',
#   'one',
#   'nt',
#   'help',
#   'either',
#   'mayb',
#   'dump',
#   'photo',
#   'screen',
#   'low',
#   'level',
#   'code',
#   'year',
#   'ago',
#   'friend',
#   'took',
#   'two',
#   'five',
#   'six',
#   'grey',
#   'level',
#   'photo',
#   'one',
#   'bit',
#   'mac',
#   'plu',
#   'screen',
#   'use',
#   'method',
#   'display',
#   'two',
#   'five',
#   'six',
#   'level',
#   'synchron',
#   'six',
#   'zero',
#   'hz',
#   'display',
#   'took',
#   'one',
#   'zero',
#   'second',
#   'experi',
#   'differ',
#   'apertur',
#   'set',
#   'screen',
#   'bright',
#   'found',
#   'rang',
#   'work',
#   'well',
#   'give',
#   'respect',
#   'contrast',
#   'qualiti',
#   'imag',
#   'pretti',
#   'good',
#   'visibl',
#   'contrast',
#   'band',
#   'minim',
#   'exposur',
#   'time',
#   'display',
#   'program',
#   'built',
#   'two',
#   'five',
#   'five',
#   'differ',
#   'one',
#   'bit',
#   'frame',
#   'first',
#   'contain',
#   'dot',
#   'pixel',
#   'valu',
#   'two',
#   'five',
#   'five',
#   'second',
#   'pixel',
#   'valu',
#   'two',
#   'five',
#   'four',
#   'etc',
#   'frame',
#   'store',
#   'use',
#   'spars',
#   'data',
#   'structur',
#   'fast',
#   'or',
#   'onto',
#   'screen',
#   'sequenc',
#   'creat',
#   'frame',
#   'sometim',
#   'took',
#   'five',
#   'one',
#   'zero',
#   'minut',
#   'old',
#   'mac',
#   'camera',
#   'shutter',
#   'close',
#   'time',
#   'anyway',
#   'ye',
#   'wrote',
#   'directli',
#   'screen',
#   'memori',
#   'mea',
#   'culpa',
#   'biggest',
#   'problem',
#   'small',
#   'imag',
#   'display',
#   'top',
#   'left',
#   'corner',
#   'screen',
#   'instead',
#   'center',
#   'took',
#   'extra',
#   'week',
#   'film',
#   'develop',
#   'print',
#   'processor',
#   'took',
#   'troubl',
#   'manual',
#   'move',
#   'imag',
#   'center',
#   'print',
#   'guess',
#   'regard',
#   'jon',
#   'rowland'],
#  ['articl',
#   'five',
#   'one',
#   'four',
#   'btg',
#   'csc',
#   'ti',
#   'com',
#   'rowland',
#   'hc',
#   'ti',
#   'com',
#   'jon',
#   'rowland',
#   'write',
#   'year',
#   'ago',
#   'friend',
#   'took',
#   'two',
#   'five',
#   'six',
#   'grey',
#   'level',
#   'photo',
#   'one',
#   'bit',
#   'mac',
#   'plu',
#   'screen',
#   'use',
#   'method',
#   'display',
#   'two',
#   'five',
#   'six',
#   'level',
#   'synchron',
#   'six',
#   'zero',
#   'hz',
#   'display',
#   'took',
#   'one',
#   'zero',
#   'second',
#   'nt',
#   'creat',
#   'eight',
#   'grey',
#   'level',
#   'imag',
#   'display',
#   'one',
#   'two',
#   'four',
#   'eight',
#   'one',
#   'six',
#   'three',
#   'two',
#   'six',
#   'four',
#   'one',
#   'two',
#   'eight',
#   'time',
#   'slice',
#   'requir',
#   'total',
#   'exposur',
#   'time',
#   'precis',
#   'time',
#   'drastic',
#   'reduc',
#   'imag',
#   'prepar',
#   'time',
#   'kenneth',
#   'sloan',
#   'comput',
#   'inform',
#   'scienc',
#   'sloan',
#   'ci',
#   'uab',
#   'edu',
#   'univers',
#   'alabama',
#   'birmingham',
#   'two',
#   'zero',
#   'five',
#   'nine',
#   'three',
#   'four',
#   'two',
#   'two',
#   'one',
#   'three',
#   'one',
#   'one',
#   'five',
#   'campbel',
#   'hall',
#   'uab',
#   'station',
#   'two',
#   'zero',
#   'five',
#   'nine',
#   'three',
#   'four',
#   'five',
#   'four',
#   'seven',
#   'three',
#   'fax',
#   'birmingham',
#   'al',
#   'three',
#   'five',
#   'two',
#   'nine',
#   'four',
#   'one',
#   'one',
#   'seven',
#   'zero'],
#  ['articl',
#   'one',
#   'four',
#   'four',
#   'zola',
#   'esd',
#   'sgi',
#   'com',
#   'erik',
#   'westworld',
#   'esd',
#   'sgi',
#   'com',
#   'erik',
#   'fortun',
#   'write',
#   'better',
#   'cdi',
#   'much',
#   'better',
#   'cdi',
#   'cours',
#   'agre',
#   'horsepow',
#   'horsepow',
#   'measur',
#   'better',
#   'full',
#   'motion',
#   'full',
#   'screen',
#   'video',
#   'yet',
#   'cd',
#   'rom',
#   'xa',
#   'start',
#   'four',
#   'quarter',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'first',
#   'three',
#   'multiplay',
#   'manufactur',
#   'panason',
#   'avail',
#   'late',
#   'year',
#   'number',
#   'manufactur',
#   'report',
#   'three',
#   'compat',
#   'box',
#   'work',
#   'manufactur',
#   'shall',
#   'see',
#   'date',
#   'inform',
#   'third',
#   'hand',
#   'worth',
#   'paid',
#   'second',
#   'hand',
#   'still',
#   'hard',
#   'look',
#   'futur',
#   'lex',
#   'van',
#   'sonderen',
#   'lex',
#   'aimla',
#   'com',
#   'philip',
#   'interact',
#   'media'],
#  ['current',
#   'look',
#   'three',
#   'graphic',
#   'librari',
#   'run',
#   'ms',
#   'window',
#   'three',
#   'one',
#   'librari',
#   'visuallib',
#   'must',
#   'run',
#   'vga',
#   'requir',
#   'add',
#   'graphic',
#   'card',
#   'visuallib',
#   'run',
#   'metawar',
#   'high',
#   'compil',
#   'three',
#   'zero',
#   'email',
#   'contact',
#   'author',
#   'visuallib',
#   'help',
#   'would',
#   'much',
#   'appreci',
#   'thank',
#   'chua',
#   'teck',
#   'joo',
#   'inform',
#   'technolog',
#   'institut',
#   'email',
#   'teckjoo',
#   'iti',
#   'gov',
#   'sg',
#   'seven',
#   'one',
#   'scienc',
#   'park',
#   'drive',
#   'phone',
#   'six',
#   'five',
#   'seven',
#   'seven',
#   'two',
#   'zero',
#   'two',
#   'three',
#   'seven',
#   'singapor',
#   'zero',
#   'five',
#   'one',
#   'one',
#   'fax',
#   'six',
#   'five',
#   'seven',
#   'seven',
#   'nine',
#   'one',
#   'eight',
#   'two',
#   'seven'],
#  ['hi',
#   'look',
#   'recommand',
#   'good',
#   'royalti',
#   'free',
#   'graphic',
#   'librari',
#   'packag',
#   'program',
#   'mainli',
#   'use',
#   'write',
#   'children',
#   'game',
#   'educ',
#   'softwar',
#   'heard',
#   'someon',
#   'mention',
#   'genu',
#   'also',
#   'gfx',
#   'good',
#   'pleas',
#   'pardon',
#   'question',
#   'sound',
#   'littl',
#   'strang',
#   'ask',
#   'question',
#   'friend',
#   'thank',
#   'advanc',
#   'carolin',
#   'tsang',
#   'cst',
#   'garfield',
#   'catt',
#   'ncsu',
#   'edu'],
#  ['articl',
#   'five',
#   'one',
#   'eyz',
#   'four',
#   'ix',
#   'optimla',
#   'aimla',
#   'com',
#   'lex',
#   'optimla',
#   'aimla',
#   'com',
#   'lex',
#   'van',
#   'sonderen',
#   'write',
#   'articl',
#   'one',
#   'four',
#   'four',
#   'zola',
#   'esd',
#   'sgi',
#   'com',
#   'erik',
#   'westworld',
#   'esd',
#   'sgi',
#   'com',
#   'erik',
#   'fortun',
#   'write',
#   'better',
#   'cdi',
#   'much',
#   'better',
#   'cdi',
#   'cours',
#   'agre',
#   'horsepow',
#   'horsepow',
#   'measur',
#   'better',
#   'full',
#   'motion',
#   'full',
#   'screen',
#   'video',
#   'yet',
#   'cd',
#   'rom',
#   'xa',
#   'start',
#   'four',
#   'quarter',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'first',
#   'three',
#   'multiplay',
#   'manufactur',
#   'panason',
#   'avail',
#   'late',
#   'year',
#   'number',
#   'manufactur',
#   'report',
#   'three',
#   'compat',
#   'box',
#   'work',
#   'manufactur',
#   'shall',
#   'see',
#   'date',
#   'three',
#   'market',
#   'rep',
#   'recent',
#   'offer',
#   'phillip',
#   'market',
#   'rep',
#   'one',
#   'zero',
#   'zero',
#   'bet',
#   'three',
#   'would',
#   'box',
#   'market',
#   'schedul',
#   'phillip',
#   'rep',
#   'declin',
#   'bet',
#   'probabl',
#   'knew',
#   'three',
#   'player',
#   'alreadi',
#   'pre',
#   'product',
#   'manufactur',
#   'run',
#   'six',
#   'month',
#   'commerci',
#   'releas',
#   'date',
#   'time',
#   'commerci',
#   'releas',
#   'manufactur',
#   'three',
#   'player',
#   'announc',
#   'possibl',
#   'alreadi',
#   'tool',
#   'product',
#   'chip',
#   'set',
#   'full',
#   'product',
#   'number',
#   'softwar',
#   'compani',
#   'design',
#   'titl',
#   'box',
#   'three',
#   'zero',
#   'zero',
#   'know',
#   'bar',
#   'road',
#   'three',
#   'headquart',
#   'last',
#   'week',
#   'folk',
#   'bullshit',
#   'littl',
#   'loudli',
#   'compani',
#   'busi',
#   'inform',
#   'third',
#   'hand',
#   'worth',
#   'paid',
#   'second',
#   'hand',
#   'still',
#   'hard',
#   'look',
#   'futur',
#   'lex',
#   'van',
#   'sonderen',
#   'lex',
#   'aimla',
#   'com',
#   'philip',
#   'interact',
#   'media',
#   'imparti',
#   'sourc'],
#  ['xref',
#   'cantaloup',
#   'srv',
#   'cs',
#   'cmu',
#   'edu',
#   'comp',
#   'lang',
#   'six',
#   'eight',
#   'zero',
#   'six',
#   'one',
#   'comp',
#   'lang',
#   'four',
#   'zero',
#   'seven',
#   'three',
#   'eight',
#   'comp',
#   'graphic',
#   'three',
#   'seven',
#   'nine',
#   'two',
#   'eight',
#   'newsgroup',
#   'comp',
#   'lang',
#   'ccomp',
#   'lang',
#   'comp',
#   'graphic',
#   'path',
#   'cantaloup',
#   'srv',
#   'cs',
#   'cmu',
#   'edu',
#   'crabappl',
#   'srv',
#   'cs',
#   'cmu',
#   'edu',
#   'fs',
#   'seven',
#   'ece',
#   'cmu',
#   'edu',
#   'europa',
#   'eng',
#   'gtefsd',
#   'com',
#   'emori',
#   'swrind',
#   'sdd',
#   'hp',
#   'com',
#   'ux',
#   'one',
#   'cso',
#   'uiuc',
#   'edu',
#   'news',
#   'cso',
#   'uiuc',
#   'edu',
#   'eehp',
#   'two',
#   'two',
#   'hl',
#   'seven',
#   'two',
#   'zero',
#   'four',
#   'hl',
#   'seven',
#   'two',
#   'zero',
#   'four',
#   'eehp',
#   'two',
#   'two',
#   'subject',
#   'graphic',
#   'librari',
#   'packag',
#   'date',
#   'tue',
#   'six',
#   'apr',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'zero',
#   'seven',
#   'zero',
#   'five',
#   'one',
#   'seven',
#   'gmt',
#   'messag',
#   'id',
#   'five',
#   'one',
#   'vot',
#   'five',
#   'news',
#   'cso',
#   'uiuc',
#   'edu',
#   'refer',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'apr',
#   'six',
#   'zero',
#   'five',
#   'one',
#   'two',
#   'zero',
#   'one',
#   'nine',
#   'five',
#   'three',
#   'five',
#   'ncsu',
#   'edu',
#   'sender',
#   'usenet',
#   'news',
#   'cso',
#   'uiuc',
#   'edu',
#   'net',
#   'nois',
#   'owner',
#   'organ',
#   'univers',
#   'illinoi',
#   'urbana',
#   'line',
#   'two'],
#  ['hi',
#   'interest',
#   'write',
#   'program',
#   'gener',
#   'sird',
#   'pictur',
#   'know',
#   'stereogram',
#   'cross',
#   'eye',
#   'pictur',
#   'becom',
#   'three',
#   'anyon',
#   'one',
#   'know',
#   'get',
#   'one',
#   'pleas',
#   'mail',
#   'steveq',
#   'sndcrft',
#   'dialix',
#   'oz',
#   'au',
#   'repli',
#   'mani',
#   'thank',
#   'help',
#   'steve'],
#  ['anybodi',
#   'know',
#   'good',
#   'two',
#   'graphic',
#   'packag',
#   'avail',
#   'ibm',
#   'rs',
#   'six',
#   'zero',
#   'zero',
#   'zero',
#   'aix',
#   'look',
#   'someth',
#   'like',
#   'dec',
#   'gk',
#   'hewlett',
#   'packard',
#   'starbas',
#   'reason',
#   'good',
#   'support',
#   'differ',
#   'output',
#   'devic',
#   'like',
#   'plotter',
#   'termin',
#   'etc',
#   'tri',
#   'also',
#   'xgk',
#   'one',
#   'one',
#   'distribut',
#   'ibm',
#   'implement',
#   'phig',
#   'work',
#   'requir',
#   'output',
#   'devic',
#   'window',
#   'salesman',
#   'ibm',
#   'familiar',
#   'graphic',
#   'expect',
#   'good',
#   'solut',
#   'ari',
#   'ari',
#   'suutari',
#   'ari',
#   'carel',
#   'fi',
#   'carelcomp',
#   'oy',
#   'lappeenranta',
#   'finland'],
#  ['mar',
#   'ixo',
#   'de',
#   'martin',
#   'stein',
#   'write',
#   'use',
#   'xwd',
#   'xpr',
#   'one',
#   'one',
#   'five',
#   'dist',
#   'variou',
#   'program',
#   'ppm',
#   'tool',
#   'print',
#   'hardcopi',
#   'color',
#   'window',
#   'problem',
#   'nt',
#   'like',
#   'xpr',
#   'give',
#   'least',
#   'one',
#   'one',
#   'four',
#   'version',
#   'louzi',
#   'output',
#   'hardcopi',
#   'look',
#   'graini',
#   'instead',
#   'use',
#   'pnmtop',
#   'take',
#   'full',
#   'advantag',
#   'postscript',
#   'let',
#   'printer',
#   'dirti',
#   'job',
#   'dither',
#   'graylevel',
#   'imag',
#   'black',
#   'white',
#   'dot',
#   'postscript',
#   'printer',
#   'tri',
#   'xwdtopnm',
#   'xwdfile',
#   'convert',
#   'ppm',
#   'ppmtopgm',
#   'graylevel',
#   'smaller',
#   'file',
#   'print',
#   'pnmtop',
#   'noturn',
#   'postscript',
#   'lpr',
#   'print',
#   'pnmtop',
#   'sever',
#   'neat',
#   'option',
#   'use',
#   'care',
#   'want',
#   'imag',
#   'four',
#   'wide',
#   'use',
#   'pnmtop',
#   'noturn',
#   'scale',
#   'one',
#   'zero',
#   'zero',
#   'width',
#   'four',
#   'noturn',
#   'prevent',
#   'imag',
#   'rotat',
#   'wider',
#   'high',
#   'width',
#   'four',
#   'specifi',
#   'paper',
#   'width',
#   'imag',
#   'width',
#   'see',
#   'scale',
#   'one',
#   'zero',
#   'zero',
#   'use',
#   'imag',
#   'small',
#   'may',
#   'fit',
#   'within',
#   'width',
#   'less',
#   'four',
#   'thu',
#   'print',
#   'smaller',
#   'four',
#   'wide',
#   'first',
#   'scale',
#   'lot',
#   'certainli',
#   'fit',
#   'four',
#   'scale',
#   'pnmtop',
#   'automat',
#   'fit',
#   'specifi',
#   'paper',
#   'width',
#   'short',
#   'pnmtop',
#   'scale',
#   'imag',
#   'fit',
#   'paper',
#   'size',
#   'blow',
#   'automat',
#   'hope',
#   'help',
#   'marcel',
#   'marcel',
#   'wijkstra',
#   'aio',
#   'wijkstra',
#   'fwi',
#   'uva',
#   'nl',
#   'faculti',
#   'mathemat',
#   'comput',
#   'scienc',
#   'univers',
#   'amsterdam',
#   'netherland',
#   'life',
#   'stink',
#   'fortun',
#   've',
#   'got',
#   'cold'],
#  ['articl',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'apr',
#   'six',
#   'zero',
#   'one',
#   'one',
#   'six',
#   'zero',
#   'five',
#   'nine',
#   'zero',
#   'nine',
#   'ci',
#   'uab',
#   'edu',
#   'sloan',
#   'ci',
#   'uab',
#   'edu',
#   'kenneth',
#   'sloan',
#   'write',
#   'nt',
#   'creat',
#   'eight',
#   'grey',
#   'level',
#   'imag',
#   'display',
#   'one',
#   'two',
#   'four',
#   'eight',
#   'one',
#   'six',
#   'three',
#   'two',
#   'six',
#   'four',
#   'one',
#   'two',
#   'eight',
#   'time',
#   'slice',
#   'eight',
#   'grey',
#   'level',
#   'imag',
#   'mean',
#   'eight',
#   'item',
#   'one',
#   'bit',
#   'imag',
#   'work',
#   'nt',
#   'work',
#   'one',
#   'bit',
#   'screen',
#   'screen',
#   'intens',
#   'non',
#   'linear',
#   'two',
#   'bit',
#   'per',
#   'pixel',
#   'could',
#   'one',
#   'one',
#   'four',
#   'two',
#   'time',
#   'give',
#   'one',
#   'six',
#   'level',
#   'linear',
#   'screen',
#   'intens',
#   'linear',
#   'one',
#   'one',
#   'two',
#   'two',
#   'work',
#   'find',
#   'best',
#   'compin',
#   'one',
#   'zero',
#   'level',
#   'one',
#   'six',
#   'chois',
#   'best',
#   'one',
#   'zero',
#   'must',
#   'chosen',
#   'differ',
#   'compin',
#   'level',
#   'vari',
#   'bit',
#   'level',
#   'keep',
#   'order',
#   'reader',
#   'verifi',
#   'wrote',
#   'juhana',
#   'kouhia'],
#  ['ca',
#   'nt',
#   'find',
#   'ctd',
#   'connect',
#   'dot',
#   'smoother',
#   'franc',
#   'commerci',
#   'program',
#   'll',
#   'happili',
#   'pay',
#   'whatev',
#   'may',
#   'cost',
#   'take',
#   'litter',
#   'pleas',
#   'help',
#   'lot',
#   'pov',
#   'sourc',
#   'textur',
#   'imag',
#   'anim',
#   'though',
#   'look',
#   'someth',
#   'tell'],
#  ['actual',
#   'tri',
#   'write',
#   'someth',
#   'like',
#   'encount',
#   'problem',
#   'amongst',
#   'draw',
#   'three',
#   'wirefram',
#   'view',
#   'quadric',
#   'quartic',
#   'requir',
#   'explicit',
#   'equat',
#   'quadric',
#   'quartic',
#   'function',
#   'paramet',
#   'convert',
#   'implicit',
#   'equat',
#   'use',
#   'pov',
#   'explicit',
#   'one',
#   'mathemat',
#   'alway',
#   'possibl',
#   'nt',
#   'enough',
#   'math',
#   'find',
#   'anybodi',
#   'heard',
#   'use',
#   'book',
#   'subject'],
#  ['articl',
#   'four',
#   'va',
#   'nine',
#   'kk',
#   'seven',
#   'tauru',
#   'cs',
#   'np',
#   'navi',
#   'mil',
#   'stockel',
#   'oahu',
#   'oc',
#   'np',
#   'navi',
#   'mil',
#   'jim',
#   'stockel',
#   'write',
#   'hi',
#   'write',
#   'data',
#   'acquisit',
#   'program',
#   'collect',
#   'data',
#   'varieti',
#   'sourc',
#   'includ',
#   'rs',
#   'two',
#   'three',
#   'two',
#   'extern',
#   'would',
#   'like',
#   'abl',
#   'display',
#   'data',
#   'near',
#   'realtim',
#   've',
#   'done',
#   'type',
#   'thing',
#   'pc',
#   'machin',
#   'unawar',
#   'graphic',
#   'packag',
#   'could',
#   'help',
#   'unix',
#   'machin',
#   'anyon',
#   'idea',
#   'commerci',
#   'free',
#   'packag',
#   'might',
#   'suit',
#   'need',
#   'would',
#   'realli',
#   'appreci',
#   'input',
#   'sure',
#   'done',
#   'mani',
#   'time',
#   'commer',
#   'packag',
#   'tri',
#   'wave',
#   'precis',
#   'visual',
#   'five',
#   'zero',
#   'five',
#   'five',
#   'three',
#   'zero',
#   'six',
#   'five',
#   'six',
#   'three',
#   'free',
#   'packag',
#   'tri',
#   'khoro',
#   'univers',
#   'new',
#   'mexico',
#   'five',
#   'zero',
#   'eight',
#   'two',
#   'seven',
#   'seven',
#   'six',
#   'five',
#   'six',
#   'three',
#   'ftp',
#   'ptrg',
#   'eec',
#   'unm',
#   'edu',
#   'login',
#   'anonyomu',
#   'ftp',
#   'valid',
#   'email',
#   'address',
#   'password',
#   'cd',
#   'pub',
#   'khoro',
#   'releas',
#   'get',
#   'right',
#   'place',
#   'david'],
#  ['requir',
#   'bgi',
#   'driver',
#   'super',
#   'vga',
#   'display',
#   'super',
#   'xvga',
#   'display',
#   'anyon',
#   'know',
#   'could',
#   'obtain',
#   'relev',
#   'driver',
#   'ftp',
#   'site',
#   'regard',
#   'simon',
#   'crow'],
#  ['kjb',
#   'mgl',
#   'uvesa',
#   'three',
#   'two',
#   'zip',
#   'univers',
#   'vesa',
#   'driver',
#   'support',
#   'video',
#   'board',
#   'chipset',
#   'includ',
#   'speedstar',
#   'two',
#   'four',
#   'two',
#   'four',
#   'two',
#   'four',
#   'bit',
#   'color',
#   'terri',
#   've',
#   'tri',
#   'speedstar',
#   'two',
#   'four',
#   'two',
#   'four',
#   'work',
#   'softwar',
#   'instanc',
#   'nt',
#   'work',
#   'anim',
#   'pro',
#   'autodesk',
#   'ca',
#   'nt',
#   'detect',
#   'svga',
#   'mode',
#   'run',
#   'univesa',
#   'realli',
#   'problem',
#   'need',
#   'vesa',
#   'driver',
#   'aa',
#   'pro',
#   'hi',
#   'color',
#   'stuff',
#   'curios',
#   'use',
#   'latest',
#   'version',
#   'three',
#   'two',
#   'version',
#   'previou',
#   'fill',
#   'capabl',
#   'bit',
#   'inform',
#   'correctli',
#   'problem',
#   'lot',
#   'softwar',
#   'got',
#   'version',
#   'nt',
#   'think',
#   'author',
#   'got',
#   'around',
#   'post',
#   'announcementof',
#   'least',
#   'miss',
#   'three',
#   'two',
#   'avail',
#   'directori',
#   'indic',
#   'three',
#   'two',
#   'nine',
#   'sure',
#   'use',
#   'version',
#   'three',
#   'two',
#   'work',
#   'fine',
#   'softwar',
#   'anim',
#   'pro',
#   'one',
#   'quit',
#   'import',
#   'pretti',
#   'useless',
#   'program',
#   'without',
#   'thing',
#   'work',
#   'imho',
#   'hope',
#   'author',
#   'fix',
#   'daniel',
#   'daniel',
#   'falk',
#   'nt',
#   'quot',
#   'comment',
#   'ebenezum',
#   'great',
#   'wizard',
#   'nine',
#   'one',
#   'fad',
#   'tekn',
#   'hj',
#   'se',
#   'nine',
#   'one',
#   'fad',
#   'hjd',
#   'nine',
#   'zero',
#   'hj',
#   'se',
#   'also',
#   'known',
#   'mega',
#   'famou',
#   'musician',
#   'jkpg',
#   'sweeeeeden',
#   'leinad',
#   'yellow',
#   'one'],
#  ['bear',
#   'new',
#   'game',
#   'could',
#   'anyon',
#   'explain',
#   'exactli',
#   'dmorf',
#   'simpli',
#   'fade',
#   'one',
#   'bitmap',
#   'anoth',
#   'shape',
#   'one',
#   'bitma',
#   'anoth',
#   'pleas',
#   'excus',
#   'ignor',
#   'even',
#   'sure',
#   've',
#   'post',
#   'thi',
#   'messag',
#   'correctli'],
#  ['pleas',
#   'bear',
#   'new',
#   'game',
#   'apolog',
#   'unreservedli',
#   'hav',
#   'post',
#   'anoth',
#   'messag',
#   'earlier',
#   'mistak',
#   'digress',
#   'could',
#   'anyon',
#   'th',
#   'ere',
#   'pleas',
#   'explain',
#   'exactli',
#   'dmorf',
#   'dtax',
#   'exe',
#   'simpli',
#   'fade',
#   'one',
#   'bitmap',
#   'anoth',
#   'reshap',
#   'one',
#   'bitmap',
#   'anoth',
#   'excus',
#   'ignor',
#   'anc'],
#  [],
#  ['need',
#   'hit',
#   'softwar',
#   'product',
#   'encourag',
#   'softwar',
#   'sale',
#   'product',
#   'pong',
#   'pacman',
#   'visicalc',
#   'dbase',
#   'pagemak',
#   'multi',
#   'media',
#   'multi',
#   'media',
#   'digit',
#   'televis',
#   'product',
#   'alreadi',
#   'albeit',
#   'capabl',
#   'three',
#   'compel',
#   'reason',
#   'buy',
#   'yet',
#   'perhap',
#   'someon',
#   'news',
#   'group',
#   'write',
#   'hit',
#   'softwar'],
#  ['hi',
#   'immedi',
#   'need',
#   'detail',
#   'variou',
#   'graphic',
#   'compress',
#   'techniqu',
#   'know',
#   'could',
#   'obtain',
#   'descript',
#   'algo',
#   'rithm',
#   'public',
#   'domain',
#   'sourc',
#   'code',
#   'format',
#   'jpeg',
#   'gif',
#   'fractal',
#   'would',
#   'immens',
#   'grate',
#   'could',
#   'share',
#   'info',
#   'project',
#   'contempl',
#   'thank',
#   'advanc',
#   'pleas',
#   'repli',
#   'via',
#   'mail',
#   'possibl',
#   'hbj'],
#  ['render',
#   'program',
#   'requir',
#   'surfac',
#   'normal',
#   'point',
#   'direct',
#   'ie',
#   'close',
#   'cube',
#   'normal',
#   'point',
#   'outward',
#   'use',
#   'point',
#   'face',
#   'determin',
#   'direct',
#   'normal',
#   'make',
#   'sure',
#   'point',
#   'either',
#   'clockwis',
#   'counter',
#   'clockwis',
#   'order',
#   'go',
#   'orient',
#   'normal',
#   'direct',
#   'given',
#   'set',
#   'point',
#   'edg',
#   'face',
#   'say',
#   'cube',
#   'face',
#   'normal',
#   'face',
#   'outward',
#   'except',
#   'one',
#   'face',
#   'best',
#   'way',
#   'realiz',
#   'face',
#   'flip',
#   'point',
#   'order',
#   'thought',
#   'good',
#   'way',
#   'tell',
#   'realiz',
#   'algorithm',
#   'would',
#   'tell',
#   'point',
#   'clockwis',
#   'order',
#   'two',
#   'polygon',
#   'like',
#   'someth',
#   'three',
#   'data',
#   'hint',
#   'tip',
#   'refer',
#   'would',
#   'appreci',
#   'steve',
#   'humor',
#   'concern',
#   'standard',
#   'one',
#   'say',
#   'good',
#   'bad',
#   'although',
#   'sure',
#   'everyon',
#   'john',
#   'kenneth',
#   'galbraith',
#   'opinion'],
#  ['wgt',
#   'wordup',
#   'graphic',
#   'toolkit',
#   'design',
#   'truli',
#   'co',
#   'programm',
#   'brother',
#   'chri',
#   'egert',
#   'turbo',
#   'borland',
#   'graphic',
#   'librari',
#   'program',
#   'three',
#   'two',
#   'zero',
#   'two',
#   'zero',
#   'zero',
#   'two',
#   'five',
#   'six',
#   'vga',
#   'current',
#   'produc',
#   'sharewar',
#   'year',
#   'may',
#   'commerci',
#   'product',
#   'excus',
#   'typo',
#   'backspac',
#   'termin',
#   'featur',
#   'includ',
#   'load',
#   'save',
#   'bit',
#   'imag',
#   'call',
#   'block',
#   'herein',
#   'flip',
#   'resiz',
#   'warp',
#   'block',
#   'load',
#   'save',
#   'palett',
#   'fade',
#   'sever',
#   'memori',
#   'graphic',
#   'primit',
#   'line',
#   'circl',
#   'bar',
#   'rectangl',
#   'region',
#   'fill',
#   'usual',
#   'useless',
#   'floodfil',
#   'sprite',
#   'anim',
#   'bitmap',
#   'two',
#   'zero',
#   'zero',
#   'onscreen',
#   'joystick',
#   'mous',
#   'support',
#   'sb',
#   'support',
#   'voc',
#   'cmf',
#   'tile',
#   'base',
#   'game',
#   'creation',
#   'use',
#   'one',
#   'six',
#   'one',
#   'six',
#   'pixel',
#   'tile',
#   'creat',
#   'three',
#   'two',
#   'zero',
#   'two',
#   'zero',
#   'zero',
#   'tile',
#   'map',
#   'game',
#   'world',
#   'like',
#   'duke',
#   'nuke',
#   'em',
#   'number',
#   'sprite',
#   'increas',
#   'one',
#   'zero',
#   'zero',
#   'zero',
#   'profession',
#   'sprite',
#   'creator',
#   'util',
#   'map',
#   'maker',
#   'routin',
#   'simplifi',
#   'scroll',
#   'game',
#   'use',
#   'map',
#   'etc',
#   'fli',
#   'play',
#   'routin',
#   'sprite',
#   'anim',
#   'fli',
#   'play',
#   'pcx',
#   'support',
#   'soon',
#   'gif',
#   'em',
#   'xm',
#   'come',
#   'soon',
#   'well',
#   'leav',
#   'mail',
#   'barri',
#   'egert',
#   'egert',
#   'obelix',
#   'gaul',
#   'csd',
#   'uwo',
#   'ca',
#   'file',
#   'avail',
#   'use',
#   'mget',
#   'wgt',
#   'zip',
#   'simtel',
#   'two',
#   'zero',
#   'mirror',
#   'pd',
#   'one',
#   'msdo',
#   'turbo',
#   'nic',
#   'funet',
#   'fi',
#   'pub',
#   'msdo',
#   'game',
#   'program',
#   'site',
#   'may',
#   'recent',
#   'file',
#   'contact',
#   'info',
#   'regard',
#   'date',
#   'inform'],
#  ['contact',
#   'signawar',
#   'corp',
#   'eight',
#   'zero',
#   'zero',
#   'four',
#   'five',
#   'eight',
#   'three',
#   'eight',
#   'two',
#   'zero',
#   'eight',
#   'zero',
#   'zero',
#   'six',
#   'three',
#   'seven',
#   'six',
#   'five',
#   'six',
#   'four',
#   'origin',
#   'memo',
#   'bcc',
#   'vincent',
#   'wall',
#   'imag',
#   'club',
#   'subject',
#   'signatur',
#   'verif',
#   'date',
#   'sent',
#   'zero',
#   'five',
#   'zero',
#   'four',
#   'nine',
#   'three',
#   'sci',
#   'imag',
#   'process',
#   'yyqi',
#   'ece',
#   'arizona',
#   'edu',
#   'yingyong',
#   'qi',
#   'subject',
#   'signatur',
#   'imag',
#   'databas',
#   'organ',
#   'arizona',
#   'electr',
#   'comput',
#   'engin',
#   'hi',
#   'could',
#   'someon',
#   'tell',
#   'databas',
#   'handwrit',
#   'signatur',
#   'imag',
#   'avail',
#   'evalu',
#   'signatur',
#   'verif',
#   'system',
#   'thank',
#   'yy'],
#  ['articl',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'apr',
#   'six',
#   'one',
#   'seven',
#   'five',
#   'one',
#   'one',
#   'seven',
#   'one',
#   'eight',
#   'four',
#   'eight',
#   'ci',
#   'uab',
#   'edu',
#   'sloan',
#   'ci',
#   'uab',
#   'edu',
#   'kenneth',
#   'sloan',
#   'write',
#   'brilliant',
#   'algorithm',
#   'serious',
#   'correct',
#   'sign',
#   'chang',
#   'flaw',
#   'obviou',
#   'therefor',
#   'shown',
#   'sorri',
#   'kenneth',
#   'sloan',
#   'comput',
#   'inform',
#   'scienc',
#   'sloan',
#   'ci',
#   'uab',
#   'edu',
#   'univers',
#   'alabama',
#   'birmingham',
#   'two',
#   'zero',
#   'five',
#   'nine',
#   'three',
#   'four',
#   'two',
#   'two',
#   'one',
#   'three',
#   'one',
#   'one',
#   'five',
#   'campbel',
#   'hall',
#   'uab',
#   'station',
#   'two',
#   'zero',
#   'five',
#   'nine',
#   'three',
#   'four',
#   'five',
#   'four',
#   'seven',
#   'three',
#   'fax',
#   'birmingham',
#   'al',
#   'three',
#   'five',
#   'two',
#   'nine',
#   'four',
#   'one',
#   'one',
#   'seven',
#   'zero'],
#  ['sorri',
#   'genoa',
#   'card',
#   'noth',
#   'ati',
#   'ultra',
#   'plu',
#   'two',
#   'mb',
#   'ca',
#   'nt',
#   'plu',
#   'ati',
#   'cost',
#   'three',
#   'three',
#   'zero',
#   'us',
#   'street',
#   'price'],
#  ['articl',
#   'one',
#   'pscti',
#   'aqe',
#   'travi',
#   'csd',
#   'harri',
#   'com',
#   'srp',
#   'travi',
#   'csd',
#   'harri',
#   'com',
#   'stephen',
#   'pietrowicz',
#   'write',
#   'go',
#   'orient',
#   'normal',
#   'direct',
#   'given',
#   'set',
#   'point',
#   'edg',
#   'face',
#   'look',
#   'edg',
#   'inconsist',
#   'consid',
#   'two',
#   'vertic',
#   'connect',
#   'least',
#   'one',
#   'edg',
#   'pq',
#   'edg',
#   'qp',
#   'appear',
#   'pq',
#   'qp',
#   'appear',
#   'edg',
#   'surfac',
#   'flip',
#   'travel',
#   'across',
#   'edg',
#   'bad',
#   'assum',
#   'warn',
#   'warn',
#   'warn',
#   'otherwis',
#   'accept',
#   'surfac',
#   'pick',
#   'edg',
#   'edg',
#   'travers',
#   'surfac',
#   'enforc',
#   'consist',
#   'edg',
#   'zero',
#   'pick',
#   'edg',
#   'pq',
#   'mark',
#   'ok',
#   'one',
#   'face',
#   'contain',
#   'edg',
#   'two',
#   'oop',
#   'make',
#   'sure',
#   'edg',
#   'consist',
#   'face',
#   'pq',
#   'qr',
#   'rs',
#   'st',
#   'tp',
#   'flip',
#   'wrong',
#   'mark',
#   'edg',
#   'ok',
#   'add',
#   'queue',
#   'check',
#   'duplic',
#   'especi',
#   'inconsist',
#   'nt',
#   'let',
#   'queue',
#   'pq',
#   'qp',
#   'two',
#   'remov',
#   'edg',
#   'queue',
#   'go',
#   'one',
#   'mark',
#   'edg',
#   'discov',
#   'inconsist',
#   'lose',
#   'step',
#   'one',
#   'find',
#   'one',
#   'face',
#   'share',
#   'particular',
#   'edg',
#   'lose',
#   'otherwis',
#   'done',
#   'edg',
#   'consist',
#   'mean',
#   'surfac',
#   'normal',
#   'either',
#   'point',
#   'decid',
#   'way',
#   'left',
#   'exercis',
#   'kenneth',
#   'sloan',
#   'comput',
#   'inform',
#   'scienc',
#   'sloan',
#   'ci',
#   'uab',
#   'edu',
#   'univers',
#   'alabama',
#   'birmingham',
#   'two',
#   'zero',
#   'five',
#   'nine',
#   'three',
#   'four',
#   'two',
#   'two',
#   'one',
#   'three',
#   'one',
#   'one',
#   'five',
#   'campbel',
#   'hall',
#   'uab',
#   'station',
#   'two',
#   'zero',
#   'five',
#   'nine',
#   'three',
#   'four',
#   'five',
#   'four',
#   'seven',
#   'three',
#   'fax',
#   'birmingham',
#   'al',
#   'three',
#   'five',
#   'two',
#   'nine',
#   'four',
#   'one',
#   'one',
#   'seven',
#   'zero'],
#  ['one',
#   'pscti',
#   'aqe',
#   'travi',
#   'csd',
#   'harri',
#   'com',
#   'srp',
#   'travi',
#   'csd',
#   'harri',
#   'com',
#   'stephen',
#   'pietrowicz',
#   'write',
#   'go',
#   'orient',
#   'normal',
#   'direct',
#   'given',
#   'set',
#   'point',
#   'edg',
#   'face',
#   'algorithm',
#   'work',
#   'well',
#   'algorithm',
#   'attempt',
#   'find',
#   'outward',
#   'face',
#   'normal',
#   'first',
#   'mark',
#   'face',
#   'unknown',
#   'creat',
#   'edg',
#   'dictionari',
#   'allow',
#   'find',
#   'face',
#   'share',
#   'given',
#   'edg',
#   'edg',
#   'two',
#   'integ',
#   'repres',
#   'two',
#   'share',
#   'vertic',
#   'pick',
#   'arbitrari',
#   'face',
#   'mark',
#   'counter',
#   'clockwis',
#   'use',
#   'edg',
#   'dictionari',
#   'orient',
#   'surround',
#   'face',
#   'base',
#   'orient',
#   'face',
#   'recurs',
#   'surround',
#   'face',
#   'consist',
#   'orient',
#   'entir',
#   'surfac',
#   'find',
#   'averag',
#   'vertic',
#   'surfac',
#   'use',
#   'point',
#   'calcul',
#   'volum',
#   'measur',
#   'take',
#   'account',
#   'face',
#   'orient',
#   'volum',
#   'turn',
#   'posit',
#   'assum',
#   'face',
#   'orient',
#   'correctli',
#   'neg',
#   'revers',
#   'orient',
#   'mark',
#   'clockwis',
#   'face',
#   'still',
#   'unknown',
#   'choos',
#   'anoth',
#   'face',
#   'go',
#   'algorithm',
#   'end',
#   'face',
#   'mark',
#   'clockwis',
#   'must',
#   'indic',
#   'revers',
#   'facet',
#   'normal',
#   'found',
#   'note',
#   'run',
#   'silicon',
#   'graphic',
#   'machin',
#   'buy',
#   'iri',
#   'inventor',
#   'three',
#   'toolkit',
#   'develop',
#   'packag',
#   'sourc',
#   'algorithm',
#   'see',
#   'usr',
#   'src',
#   'inventor',
#   'tool',
#   'ivnorm',
#   're',
#   'sorri',
#   'ca',
#   'nt',
#   'give',
#   'sourc',
#   'even',
#   'could',
#   'reli',
#   'heavili',
#   'inventor',
#   'gavin',
#   'gavin',
#   'sgi',
#   'com',
#   'four',
#   'one',
#   'five',
#   'three',
#   'nine',
#   'zero',
#   'one',
#   'zero',
#   'two',
#   'four'],
#  ['andrey',
#   'cco',
#   'caltech',
#   'edu',
#   'andr',
#   'yew',
#   'write',
#   'nine',
#   'hh',
#   'dtek',
#   'chalmer',
#   'se',
#   'henrik',
#   'harmsen',
#   'write',
#   'one',
#   'four',
#   'bit',
#   'per',
#   'give',
#   'horribl',
#   'machband',
#   'visibl',
#   'almost',
#   'pictur',
#   'five',
#   'bit',
#   'per',
#   'three',
#   'two',
#   'seven',
#   'six',
#   'eight',
#   'six',
#   'five',
#   'zero',
#   'zero',
#   'zero',
#   'color',
#   'give',
#   'visibl',
#   'machband',
#   'color',
#   'gradient',
#   'pictur',
#   'almost',
#   'machband',
#   'color',
#   'resolut',
#   'see',
#   'small',
#   'machband',
#   'smooth',
#   'color',
#   'gradient',
#   'pictur',
#   'situiat',
#   'get',
#   'visibl',
#   'mach',
#   'band',
#   'even',
#   'two',
#   'four',
#   'bit',
#   'card',
#   'creat',
#   'smooth',
#   'color',
#   'gradient',
#   'dark',
#   'green',
#   'white',
#   'yellow',
#   'someth',
#   'turn',
#   'contrast',
#   'monitor',
#   'probabl',
#   'see',
#   'mach',
#   'band',
#   'nt',
#   'mean',
#   'damn',
#   'henrik',
#   'attempt',
#   'help',
#   'use',
#   'common',
#   'misconcept',
#   'correct',
#   'mach',
#   'band',
#   'occur',
#   'imag',
#   'color',
#   'quantiz',
#   'see',
#   'nt',
#   'enough',
#   'bit',
#   'human',
#   'eye',
#   'respons',
#   'transit',
#   'edg',
#   'intens',
#   'result',
#   'color',
#   'near',
#   'transist',
#   'look',
#   'brighter',
#   'brighter',
#   'side',
#   'darker',
#   'darker',
#   'side',
#   'andr',
#   'yeah',
#   'cours',
#   'term',
#   'mach',
#   'band',
#   'correct',
#   'one',
#   've',
#   'color',
#   'quantiz',
#   'effect',
#   'although',
#   'bad',
#   'color',
#   'quantiz',
#   'effect',
#   'could',
#   'result',
#   'visibl',
#   'mach',
#   'band',
#   'pictur',
#   'smooth',
#   'quantizis',
#   'henrik',
#   'harmsen',
#   'internet',
#   'nine',
#   'hh',
#   'dtek',
#   'chalmer',
#   'se',
#   'chalmer',
#   'univers',
#   'technolog',
#   'sweden',
#   'nt',
#   'lost',
#   'mind',
#   'back',
#   'tape',
#   'somewher'],
#  ['articl',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'apr',
#   'five',
#   'one',
#   'one',
#   'four',
#   'four',
#   'two',
#   'eight',
#   'two',
#   'zero',
#   'six',
#   'one',
#   'falcon',
#   'aamrl',
#   'wpafb',
#   'af',
#   'mil',
#   'dsnyder',
#   'falcon',
#   'aamrl',
#   'wpafb',
#   'af',
#   'mil',
#   'write',
#   'articl',
#   'four',
#   'va',
#   'nine',
#   'kk',
#   'seven',
#   'tauru',
#   'cs',
#   'np',
#   'navi',
#   'mil',
#   'stockel',
#   'oahu',
#   'oc',
#   'np',
#   'navi',
#   'mil',
#   'jim',
#   'stockel',
#   'write',
#   'hi',
#   'opp',
#   'type',
#   'phone',
#   'number',
#   'wrong',
#   'correct',
#   'number',
#   'commer',
#   'packag',
#   'tri',
#   'wave',
#   'precis',
#   'visual',
#   'three',
#   'zero',
#   'three',
#   'five',
#   'three',
#   'zero',
#   'nine',
#   'zero',
#   'zero',
#   'zero',
#   'free',
#   'packag',
#   'tri',
#   'khoro',
#   'univers',
#   'new',
#   'mexico',
#   'five',
#   'zero',
#   'five',
#   'two',
#   'seven',
#   'seven',
#   'six',
#   'five',
#   'six',
#   'three',
#   'ftp',
#   'ptrg',
#   'eec',
#   'unm',
#   'edu',
#   'login',
#   'anonyomu',
#   'ftp',
#   'valid',
#   'email',
#   'address',
#   'password',
#   'cd',
#   'pub',
#   'khoro',
#   'releas'],
#  ['anybodi',
#   'know',
#   'ige',
#   'viewer',
#   'do',
#   'window',
#   'need',
#   'abl',
#   'display',
#   'computervis',
#   'ige',
#   'file',
#   'pc',
#   'run',
#   'window',
#   'three',
#   'one',
#   'thank',
#   'advanc',
#   'brian',
#   'safford',
#   'email',
#   'bsaffo',
#   'zero',
#   'one',
#   'cad',
#   'gmed',
#   'com',
#   'electron',
#   'data',
#   'system',
#   'phone',
#   'three',
#   'one',
#   'three',
#   'six',
#   'nine',
#   'six',
#   'six',
#   'three',
#   'zero',
#   'two',
#   'note',
#   'view',
#   'opinion',
#   'express',
#   'herein',
#   'mine',
#   'reflect',
#   'electron',
#   'data',
#   'system',
#   'corp'],
#  ['help',
#   'friend',
#   'class',
#   'project',
#   'tri',
#   'make',
#   'comput',
#   'anim',
#   'movi',
#   'sort',
#   'disney',
#   'anim',
#   'would',
#   'like',
#   'put',
#   'vcr',
#   'possibl',
#   'easi',
#   'rel',
#   'cheap',
#   'three',
#   'eight',
#   'six',
#   'ibm',
#   'compat',
#   'rel',
#   'clueless',
#   'comput',
#   'could',
#   'help',
#   'pleas',
#   'thanx',
#   'brant',
#   'ritter',
#   'mosh',
#   'cosmic',
#   'cesspool',
#   'physic',
#   'delight',
#   'kieda',
#   'rhcp'],
#  ['interest',
#   'inform',
#   'stereoscop',
#   'imag',
#   'sun',
#   'workstat',
#   'part',
#   'need',
#   'know',
#   'hardwar',
#   'avail',
#   'interfac',
#   'system',
#   'whether',
#   'refresh',
#   'rate',
#   'suffici',
#   'produc',
#   'qualiti',
#   'imag',
#   'represent',
#   'inform',
#   'subject',
#   'would',
#   'greatli',
#   'appreci',
#   'thank'],
#  ['articl',
#   'seven',
#   'one',
#   'five',
#   'five',
#   'pdxgate',
#   'uucp',
#   'idr',
#   'rigel',
#   'cs',
#   'pdx',
#   'edu',
#   'ian',
#   'romanick',
#   'write',
#   'one',
#   'thing',
#   'small',
#   'chang',
#   'initi',
#   'condit',
#   'caus',
#   'huge',
#   'chang',
#   'final',
#   'condit',
#   'certain',
#   'thing',
#   'way',
#   'plate',
#   'tektonik',
#   'volcan',
#   'activ',
#   'effect',
#   'land',
#   'scape',
#   'entir',
#   'random',
#   'unpredict',
#   'also',
#   'true',
#   'fractal',
#   'one',
#   'could',
#   'also',
#   'conclud',
#   'could',
#   'model',
#   'fractal',
#   'yeah',
#   'also',
#   'true',
#   'long',
#   'complic',
#   'sequenc',
#   'event',
#   'calcul',
#   'big',
#   'comput',
#   'program',
#   'gener',
#   'nt',
#   'argu',
#   'get',
#   'similar',
#   'mayb',
#   'use',
#   'result',
#   'fractal',
#   'question',
#   'whether',
#   'fractal',
#   'fiend',
#   'seem',
#   'say',
#   'part',
#   'system',
#   'ca',
#   'nt',
#   'model',
#   'replac',
#   'random',
#   'number',
#   'gener',
#   'use',
#   'instanc',
#   'make',
#   'data',
#   'palat',
#   'human',
#   'percept',
#   'tortur',
#   'test',
#   'rest',
#   'system',
#   'nt',
#   'think',
#   'much',
#   'fractal',
#   'certainli',
#   'would',
#   'rather',
#   'model',
#   'improv',
#   'explic',
#   'manner',
#   'guess',
#   'nt',
#   'seen',
#   'earth',
#   'shake',
#   'fractal',
#   'model',
#   'explain',
#   'correl',
#   'univers',
#   'actual',
#   'exist',
#   'realli',
#   'hope',
#   'hold',
#   'self',
#   'similar',
#   'breath',
#   'one',
#   'thing',
#   'fractal',
#   'good',
#   'fractal',
#   'imag',
#   'compress',
#   'uh',
#   'huh',
#   'll',
#   'believ',
#   'see',
#   've',
#   'chase',
#   'fractal',
#   'compress',
#   'year',
#   'still',
#   'nt',
#   'believ',
#   'great',
#   'come',
#   'nt',
#   'see',
#   'compet',
#   'jpeg',
#   'caus',
#   'ca',
#   'nt',
#   'll',
#   'wager',
#   'actual',
#   'wager',
#   'quit',
#   'tri',
#   'make',
#   'fractal',
#   'compress',
#   'work',
#   'tri',
#   'nt',
#   'think',
#   'reason',
#   'altern',
#   'techniqu',
#   'neat',
#   'though',
#   'll',
#   'reiter',
#   'disbelief',
#   'everyth',
#   'fractal',
#   'nt',
#   'think',
#   'fractal',
#   'compress',
#   'wide',
#   'explain',
#   'practic',
#   'know',
#   'barnsley',
#   'sloan',
#   'trick',
#   'sleev',
#   'make',
#   'demo',
#   'work',
#   'nt',
#   'see',
#   'anyon',
#   'use',
#   'real',
#   'product',
#   'six',
#   'year',
#   'sinc',
#   'iter',
#   'system',
#   'form',
#   'right',
#   'alway',
#   'go',
#   'question',
#   'product',
#   'sloan',
#   'repli',
#   'compani',
#   'plan',
#   'ship',
#   'first',
#   'encod',
#   'devic',
#   'summer',
#   'say',
#   'march',
#   'iter',
#   'system',
#   'half',
#   'system',
#   'decod',
#   'scientif',
#   'american',
#   'march',
#   'one',
#   'nine',
#   'nine',
#   'zero',
#   'page',
#   'seven',
#   'seven',
#   'allen',
#   'nt',
#   'even',
#   'get',
#   'start'],
#  ['complex',
#   'bio',
#   'medic',
#   'imag',
#   'avail',
#   'anywher',
#   'net',
#   'experiment',
#   'complex',
#   'mean',
#   'everi',
#   'sampl',
#   'data',
#   'point',
#   'magnitud',
#   'phase',
#   'inform',
#   'thank',
#   'pointer',
#   'vishwa'],
#  ['anyon',
#   'know',
#   'ftp',
#   'mpeg',
#   'do',
#   'thank',
#   'help',
#   'advanc',
#   'email',
#   'prefer',
#   'post',
#   'fine',
#   'scott',
#   'lord',
#   'soth',
#   'knight',
#   'email',
#   'lordsoth',
#   'uiuc',
#   'black',
#   'rose',
#   'next',
#   'sa',
#   'five',
#   'eight',
#   'two',
#   'nine',
#   'five',
#   'sumter',
#   'cso',
#   'uiuc',
#   'edu',
#   'clue',
#   'want',
#   'say',
#   'wo',
#   'nt',
#   'say',
# ...
#   'heard',
#   'done',
#   'love',
#   'hear',
#   'mike',
#   'mcconnel',
#   'emm',
#   'cray',
#   'com'],
#  ['sorri',
#   'miss',
#   'raymond',
#   'dahlgren',
#   'last',
#   'month',
#   'virtual',
#   'realiti',
#   'market',
#   'manag',
#   'silicon',
#   'graphic',
#   'perhap',
#   'help',
#   'littl',
#   'articl',
#   'one',
#   'nine',
#   'nine',
#   'three',
#   'mar',
#   'one',
#   'seven',
#   'one',
#   'eight',
#   'five',
#   'seven',
#   'two',
#   'five',
#   'one',
#   'three',
#   'four',
#   'eight',
#   'seven',
#   'relay',
#   'nswc',
#   'navi',
#   'mil',
#   'rchui',
#   'nswc',
#   'wo',
#   'nswc',
#   'navi',
#   'mil',
#   'raymond',
#   'chui',
#   'write',
#   'hello',
#   'real',
#   'realiti',
#   'agenc',
#   'start',
#   'express',
#   'interest',
#   'virtual',
#   'realiti',
#   'vr',
#   'far',
#   'know',
#   'much',
#   'vr',
#   'know',
#   'hollywood',
#   'movi',
#   'terminat',
#   'two',
#   'lawnmov',
#   'man',
#   'also',
#   'know',
#   'someth',
#   'vr',
#   'abc',
#   'news',
#   'magazin',
#   'comput',
#   'graphic',
#   'world',
#   'magazin',
#   'unfortun',
#   'sgi',
#   'system',
#   'use',
#   'creat',
#   'special',
#   'effect',
#   'termin',
#   'two',
#   'lawnmow',
#   'man',
#   'film',
#   'qualiti',
#   'comput',
#   'graphic',
#   'render',
#   'softwar',
#   'written',
#   'film',
#   'frame',
#   'time',
#   'frame',
#   'comput',
#   'anim',
#   'film',
#   'took',
#   'hour',
#   'render',
#   'high',
#   'end',
#   'parallel',
#   'process',
#   'comput',
#   'system',
#   'thu',
#   'level',
#   'graphic',
#   'would',
#   'difficult',
#   'imposs',
#   'acheiv',
#   'real',
#   'time',
#   'three',
#   'zero',
#   'frame',
#   'per',
#   'second',
#   'certainli',
#   'want',
#   'know',
#   'vr',
#   'lead',
#   'compani',
#   'agenc',
#   'univers',
#   'machin',
#   'support',
#   'vr',
#   'sgi',
#   'sun',
#   'four',
#   'hp',
#   'nine',
#   'zero',
#   'zero',
#   'zero',
#   'bim',
#   'six',
#   'zero',
#   'zero',
#   'zero',
#   'etc',
#   'depend',
#   'upon',
#   'seriou',
#   'advanc',
#   'applic',
#   'true',
#   'immers',
#   'visual',
#   'vr',
#   'requir',
#   'render',
#   'complex',
#   'visual',
#   'databas',
#   'anywher',
#   'two',
#   'zero',
#   'six',
#   'zero',
#   'newli',
#   'render',
#   'frame',
#   'per',
#   'second',
#   'similar',
#   'requir',
#   'tradit',
#   'flight',
#   'simul',
#   'pilot',
#   'train',
#   'frame',
#   'rate',
#   'low',
#   'user',
#   'notic',
#   'step',
#   'frame',
#   'move',
#   'head',
#   'rapidli',
#   'around',
#   'scene',
#   'motion',
#   'graphic',
#   'smooth',
#   'contigu',
#   'thu',
#   'graphic',
#   'system',
#   'must',
#   'power',
#   'enough',
#   'sustain',
#   'high',
#   'frame',
#   'rate',
#   'render',
#   'complex',
#   'data',
#   'represent',
#   'addit',
#   'frame',
#   'rate',
#   'must',
#   'constant',
#   'system',
#   'render',
#   'one',
#   'five',
#   'frame',
#   'per',
#   'second',
#   'one',
#   'point',
#   'six',
#   'zero',
#   'frame',
#   'per',
#   'second',
#   'next',
#   'perhap',
#   'due',
#   'scene',
#   'new',
#   'view',
#   'direct',
#   'simpler',
#   'visibl',
#   'user',
#   'get',
#   'heavili',
#   'distract',
#   'medium',
#   'graphic',
#   'comput',
#   'rather',
#   'focus',
#   'data',
#   'maintain',
#   'constant',
#   'frame',
#   'rate',
#   'system',
#   'must',
#   'abl',
#   'run',
#   'real',
#   'time',
#   'unix',
#   'gener',
#   'support',
#   'real',
#   'time',
#   'oper',
#   'silicon',
#   'graphic',
#   'modifi',
#   'unix',
#   'kernel',
#   'multi',
#   'processor',
#   'system',
#   'abl',
#   'support',
#   'real',
#   'time',
#   'oper',
#   'bypass',
#   'usual',
#   'unix',
#   'process',
#   'prioriti',
#   'manag',
#   'scheme',
#   'uniprocessor',
#   'system',
#   'run',
#   'unix',
#   'fundament',
#   'support',
#   'real',
#   'time',
#   'oper',
#   'sun',
#   'sparc',
#   'one',
#   'zero',
#   'hp',
#   'seven',
#   'zero',
#   'zero',
#   'seri',
#   'system',
#   'ibm',
#   'rs',
#   'six',
#   'zero',
#   'zero',
#   'zero',
#   'even',
#   'sgi',
#   'uniprocessor',
#   'system',
#   'like',
#   'indigo',
#   'crimson',
#   'multiprocessor',
#   'onyx',
#   'challeng',
#   'system',
#   'support',
#   'real',
#   'time',
#   'oper',
#   'due',
#   'symmetr',
#   'multi',
#   'process',
#   'smp',
#   'share',
#   'memori',
#   'architectur',
#   'graphic',
#   'perspect',
#   'render',
#   'complex',
#   'virtual',
#   'environ',
#   'requir',
#   'advanc',
#   'render',
#   'techniqu',
#   'like',
#   'textur',
#   'map',
#   'real',
#   'time',
#   'multi',
#   'sampl',
#   'anti',
#   'alias',
#   'gener',
#   'purpos',
#   'graphic',
#   'system',
#   'market',
#   'today',
#   'crimson',
#   'realityengin',
#   'onyx',
#   'realityengin',
#   'two',
#   'system',
#   'fulli',
#   'support',
#   'capabl',
#   'anti',
#   'alias',
#   'particularli',
#   'import',
#   'crawl',
#   'jag',
#   'edg',
#   'alias',
#   'polygon',
#   'unfortun',
#   'distract',
#   'immers',
#   'virtual',
#   'environ',
#   'kind',
#   'graphic',
#   'languag',
#   'use',
#   'vr',
#   'gl',
#   'opengl',
#   'phig',
#   'pex',
#   'gk',
#   'etc',
#   'use',
#   'gener',
#   'purpos',
#   'graphic',
#   'librari',
#   'list',
#   'develop',
#   'vr',
#   'applic',
#   'start',
#   'pretti',
#   'low',
#   'level',
#   'shelf',
#   'softwar',
#   'packag',
#   'avail',
#   'get',
#   'go',
#   'much',
#   'faster',
#   'target',
#   'directli',
#   'vr',
#   'applic',
#   'develop',
#   'popular',
#   'particular',
#   'order',
#   'divis',
#   'inc',
#   'redwood',
#   'citi',
#   'ca',
#   'dv',
#   'sen',
#   'eight',
#   'inc',
#   'sausalito',
#   'ca',
#   'worldtoolkit',
#   'naval',
#   'postgradu',
#   'school',
#   'monterey',
#   'ca',
#   'npsnet',
#   'free',
#   'gemini',
#   'technolog',
#   'corp',
#   'irvin',
#   'ca',
#   'gv',
#   'simat',
#   'seri',
#   'paradigm',
#   'simul',
#   'inc',
#   'dalla',
#   'tx',
#   'visionwork',
#   'audiowork',
#   'silicon',
#   'graphic',
#   'inc',
#   'mountain',
#   'viewca',
#   'iri',
#   'perform',
#   'other',
#   'top',
#   'head',
#   'compani',
#   'make',
#   'interfac',
#   'devic',
#   'vr',
#   'goggl',
#   'boom',
#   'binocular',
#   'omni',
#   'orient',
#   'monitor',
#   'hamlet',
#   'glove',
#   'arm',
#   'etc',
#   'mani',
#   'list',
#   'smatter',
#   'fake',
#   'space',
#   'lab',
#   'menlo',
#   'parkca',
#   'boom',
#   'virtual',
#   'technolog',
#   'inc',
#   'stanford',
#   'ca',
#   'cyberglov',
#   'digit',
#   'imag',
#   'design',
#   'new',
#   'york',
#   'ny',
#   'cricket',
#   'three',
#   'input',
#   'kaiser',
#   'electro',
#   'optic',
#   'carlsbad',
#   'ca',
#   'sim',
#   'eye',
#   'helmet',
#   'display',
#   'virtual',
#   'research',
#   'sunnyval',
#   'ca',
#   'flight',
#   'helmet',
#   'display',
#   'virtual',
#   'realiti',
#   'inc',
#   'pleasantvilleni',
#   'head',
#   'mtd',
#   'display',
#   'softwar',
#   'system',
#   'san',
#   'jose',
#   'ca',
#   'three',
#   'model',
#   'softwar',
#   'etc',
#   'etc',
#   'etc',
#   'compani',
#   'address',
#   'phone',
#   'number',
#   'get',
#   'list',
#   'name',
#   'vr',
#   'expert',
#   'phone',
#   'number',
#   'email',
#   'address',
#   'read',
#   'vr',
#   'book',
#   'market',
#   'virtual',
#   'realiti',
#   'ken',
#   'piment',
#   'ken',
#   'texiera',
#   'sp',
#   'virtual',
#   'mirag',
#   'artifici',
#   'realiti',
#   'myron',
#   'kreuger',
#   'etc',
#   'check',
#   'newsgroup',
#   'sci',
#   'virtual',
#   'world',
#   'feel',
#   'free',
#   'contact',
#   'info',
#   'regard',
#   'josh',
#   'joshua',
#   'mogal',
#   'product',
#   'manag',
#   'advanc',
#   'graphic',
#   'divis',
#   'advanc',
#   'graphic',
#   'system',
#   'silicon',
#   'graphic',
#   'inc',
#   'market',
#   'manag',
#   'two',
#   'zero',
#   'one',
#   'one',
#   'north',
#   'shorelin',
#   'blvd',
#   'virtual',
#   'realiti',
#   'mountain',
#   'view',
#   'ca',
#   'nine',
#   'four',
#   'zero',
#   'three',
#   'nine',
#   'seven',
#   'three',
#   'one',
#   'one',
#   'interact',
#   'entertain',
#   'nine',
#   'five',
#   'eight',
#   'zero',
#   'tel',
#   'four',
#   'one',
#   'five',
#   'three',
#   'nine',
#   'zero',
#   'one',
#   'four',
#   'six',
#   'zero',
#   'fax',
#   'four',
#   'one',
#   'five',
#   'nine',
#   'six',
#   'four',
#   'eight',
#   'six',
#   'seven',
#   'one',
#   'mail',
#   'mogal',
#   'sgi',
#   'com'],
#  ['articl',
#   'jona',
#   'seven',
#   'three',
#   'four',
#   'eight',
#   'zero',
#   'two',
#   'nine',
#   'eight',
#   'three',
#   'gouraud',
#   'jona',
#   'isi',
#   'liu',
#   'se',
#   'jona',
#   'yngvesson',
#   'write',
#   'intersect',
#   'line',
#   'polygon',
#   'undecid',
#   'dave',
#   'baraff',
#   'tom',
#   'duff',
#   'deb',
#   'charisma',
#   'graphic',
#   'cornel',
#   'edu',
#   'recent',
#   'year',
#   'mani',
#   'geometr',
#   'problem',
#   'success',
#   'model',
#   'new',
#   'languag',
#   'call',
#   'postscript',
#   'see',
#   'postscript',
#   'languag',
#   'adob',
#   'system',
#   'incorpor',
#   'isbn',
#   'zero',
#   'two',
#   'zero',
#   'one',
#   'one',
#   'zero',
#   'one',
#   'seven',
#   'nine',
#   'three',
#   'co',
#   'one',
#   'nine',
#   'eight',
#   'five',
#   'given',
#   'line',
#   'polygon',
#   'write',
#   'postscript',
#   'program',
#   'draw',
#   'line',
#   'polygon',
#   'output',
#   'answer',
#   'output',
#   'mean',
#   'program',
#   'execut',
#   'command',
#   'call',
#   'showpag',
#   'actual',
#   'print',
#   'page',
#   'paper',
#   'contain',
#   'line',
#   'polygon',
#   'quick',
#   'examin',
#   'paper',
#   'provid',
#   'answer',
#   'reduc',
#   'problem',
#   'thu',
#   'origin',
#   'problem',
#   'curious',
#   'modern',
#   'postscript',
#   'point',
#   'polygon',
#   'problem',
#   'solv',
#   'even',
#   'easili',
#   'wit',
#   'titl',
#   'point',
#   'polygon',
#   'creator',
#   'allen',
#   'ab',
#   'cc',
#   'purdu',
#   'edu',
#   'amus',
#   'comp',
#   'graphic',
#   'regular',
#   'languagelevel',
#   'two',
#   'documentneededresourc',
#   'humor',
#   'sens',
#   'thereof',
#   'endcom',
#   'program',
#   'test',
#   'whether',
#   'point',
#   'insid',
#   'given',
#   'polygon',
#   'current',
#   'use',
#   'even',
#   'odd',
#   'rule',
#   'chang',
#   'replac',
#   'ineofil',
#   'infil',
#   'level',
#   'two',
#   'oper',
#   've',
#   'got',
#   'level',
#   'one',
#   're',
#   'luck',
#   'result',
#   'print',
#   'output',
#   'stream',
#   'caution',
#   'accur',
#   'devic',
#   'pixel',
#   'put',
#   'huge',
#   'scale',
#   'first',
#   'nt',
#   'sure',
#   'point',
#   'test',
#   'put',
#   'coordin',
#   'five',
#   'zero',
#   'seven',
#   'five',
#   'vertic',
#   'polygon',
#   'counter',
#   'clockwis',
#   'order',
#   'put',
#   'array',
#   'pair',
#   'coordin',
#   'zero',
#   'zero',
#   'one',
#   'zero',
#   'zero',
#   'zero',
#   'one',
#   'zero',
#   'zero',
#   'one',
#   'zero',
#   'zero',
#   'six',
#   'seven',
#   'one',
#   'zero',
#   'zero',
#   'six',
#   'seven',
#   'five',
#   'zero',
#   'three',
#   'three',
#   'five',
#   'zero',
#   'three',
#   'three',
#   'one',
#   'zero',
#   'zero',
#   'zero',
#   'one',
#   'zero',
#   'zero',
#   'dup',
#   'zero',
#   'get',
#   'aload',
#   'pop',
#   'moveto',
#   'dup',
#   'length',
#   'one',
#   'dup',
#   'three',
#   'one',
#   'roll',
#   'sub',
#   'getinterv',
#   'aload',
#   'pop',
#   'lineto',
#   'foral',
#   'closepath',
#   'ineofil',
#   'ye',
#   'ifels'],
#  ['hi',
#   'everyon',
#   'thought',
#   'peopl',
#   'may',
#   'interest',
#   'vr',
#   'softwar',
#   'group',
#   'announc',
#   'releas',
#   'multivers',
#   'one',
#   'zero',
#   'two',
#   'multivers',
#   'multi',
#   'user',
#   'non',
#   'immers',
#   'window',
#   'base',
#   'virtual',
#   'realiti',
#   'system',
#   'primarili',
#   'focus',
#   'entertain',
#   'research',
#   'featur',
#   'client',
#   'server',
#   'base',
#   'model',
#   'use',
#   'berkeley',
#   'socket',
#   'limit',
#   'number',
#   'user',
#   'apart',
#   'perform',
#   'gener',
#   'client',
#   'customiz',
#   'server',
#   'hierach',
#   'object',
#   'allow',
#   'attach',
#   'camera',
#   'light',
#   'sourc',
#   'multipl',
#   'light',
#   'sourc',
#   'ambient',
#   'point',
#   'spot',
#   'object',
#   'extens',
#   'code',
#   'handl',
#   'uniqu',
#   'function',
#   'easili',
#   'attach',
#   'function',
#   'client',
#   'client',
#   'built',
#   'around',
#   'fast',
#   'render',
#   'loop',
#   'basic',
#   'chang',
#   'thing',
#   'told',
#   'server',
#   'render',
#   'imag',
#   'user',
#   'viewpoint',
#   'also',
#   'provid',
#   'server',
#   'inform',
#   'user',
#   'action',
#   'commun',
#   'client',
#   'therefor',
#   'user',
#   'client',
#   'design',
#   'gener',
#   'word',
#   'nt',
#   'need',
#   'develop',
#   'new',
#   'client',
#   'want',
#   'enter',
#   'new',
#   'world',
#   'mean',
#   'resourc',
#   'spent',
#   'enhanc',
#   'client',
#   'softwar',
#   'rather',
#   'adapt',
#   'adapt',
#   'explain',
#   'moment',
#   'occur',
#   'server',
#   'releas',
#   'client',
#   'softwar',
#   'support',
#   'follow',
#   'function',
#   'hierarch',
#   'object',
#   'associ',
#   'address',
#   'multipl',
#   'light',
#   'sourc',
#   'type',
#   'ambient',
#   'point',
#   'spot',
#   'user',
#   'interfac',
#   'panel',
#   'colour',
#   'polygon',
#   'render',
#   'phong',
#   'shade',
#   'option',
#   'wirefram',
#   'faster',
#   'frame',
#   'rate',
#   'mous',
#   'keyboard',
#   'input',
#   'peopl',
#   'may',
#   'disappoint',
#   'softwar',
#   'nt',
#   'support',
#   'powerglov',
#   'input',
#   'devic',
#   'ca',
#   'nt',
#   'nt',
#   'one',
#   'howev',
#   'one',
#   'first',
#   'enhanc',
#   'server',
#   'custom',
#   'take',
#   'place',
#   'follow',
#   'basic',
#   'support',
#   'provid',
#   'releas',
#   'potenti',
#   'world',
#   'server',
#   'develop',
#   'transpar',
#   'client',
#   'manag',
#   'client',
#   'messag',
#   'handl',
#   'may',
#   'sound',
#   'like',
#   'much',
#   'take',
#   'away',
#   'headach',
#   'accept',
#   'termin',
#   'client',
#   'receiv',
#   'messag',
#   'applic',
#   'writer',
#   'work',
#   'assumpt',
#   'thing',
#   'happen',
#   'local',
#   'thing',
#   'get',
#   'interest',
#   'object',
#   'extens',
#   'function',
#   'provid',
#   'allow',
#   'anim',
#   'object',
#   'server',
#   'select',
#   'extens',
#   'instal',
#   'mean',
#   'decid',
#   'object',
#   'extend',
#   'function',
#   'world',
#   'basic',
#   'call',
#   'extens',
#   'initialis',
#   'want',
#   'event',
#   'handler',
#   'registr',
#   'develop',
#   'extens',
#   'object',
#   'basic',
#   'write',
#   'callback',
#   'function',
#   'event',
#   'want',
#   'object',
#   'respond',
#   'current',
#   'event',
#   'support',
#   'init',
#   'move',
#   'chang',
#   'collid',
#   'termin',
#   'collis',
#   'detect',
#   'registr',
#   'want',
#   'object',
#   'respond',
#   'collis',
#   'event',
#   'provid',
#   'basic',
#   'inform',
#   'collis',
#   'detect',
#   'manag',
#   'softwar',
#   'callback',
#   'activ',
#   'collis',
#   'occur',
#   'softwar',
#   'kept',
#   'separ',
#   'worldserv',
#   'applic',
#   'applic',
#   'develop',
#   'want',
#   'build',
#   'librari',
#   'extend',
#   'object',
#   'choos',
#   'follow',
#   'need',
#   'make',
#   'world',
#   'server',
#   'applic',
#   'provid',
#   'initworld',
#   'function',
#   'choos',
#   'object',
#   'extens',
#   'support',
#   'plu',
#   'initi',
#   'want',
#   'provid',
#   'positionobject',
#   'function',
#   'determin',
#   'place',
#   'new',
#   'client',
#   'provid',
#   'installworldobject',
#   'function',
#   'load',
#   'world',
#   'wld',
#   'file',
#   'new',
#   'client',
#   'provid',
#   'getworldtyp',
#   'function',
#   'tell',
#   'new',
#   'client',
#   'persona',
#   'provid',
#   'animateworld',
#   'function',
#   'go',
#   'wild',
#   'minimum',
#   'let',
#   'object',
#   'move',
#   'call',
#   'move',
#   'function',
#   'let',
#   'server',
#   'sleep',
#   'bit',
#   'avoid',
#   'outrun',
#   'client',
#   'prove',
#   'line',
#   'count',
#   'three',
#   'world',
#   'server',
#   've',
#   'provid',
#   'gener',
#   'eight',
#   'one',
#   'line',
#   'dactyl',
#   'two',
#   'seven',
#   'zero',
#   'line',
#   'complic',
#   'collis',
#   'detect',
#   'due',
#   'stair',
#   'probabl',
#   'improv',
#   'futur',
#   'version',
#   'dogfight',
#   'seven',
#   'two',
#   'line',
#   'locat',
#   'softwar',
#   'locat',
#   'follow',
#   'site',
#   'ftp',
#   'washington',
#   'edu',
#   'directori',
#   'pub',
#   'virtual',
#   'world',
#   'file',
#   'multivers',
#   'one',
#   'zero',
#   'two',
#   'tar',
#   'futur',
#   'client',
#   'textur',
#   'map',
#   'realist',
#   'render',
#   'buffer',
#   'similar',
#   'gouraud',
#   'shade',
#   'hmd',
#   'support',
#   'etc',
#   'etc',
#   'server',
#   'physic',
#   'model',
#   'graviti',
#   'friction',
#   'etc',
#   'enhanc',
#   'object',
#   'manag',
#   'interact',
#   'etc',
#   'etc',
#   'improv',
#   'comm',
#   'hope',
#   'provid',
#   'peopl',
#   'good',
#   'understand',
#   'multivers',
#   'softwar',
#   'unfortun',
#   'come',
#   'practic',
#   'zero',
#   'document',
#   'sure',
#   'whether',
#   'ever',
#   'abl',
#   'rectifi',
#   'hope',
#   'peopl',
#   'enjoy',
#   'softwar',
#   'use',
#   'explor',
#   'virtual',
#   'univers',
#   've',
#   'certainli',
#   'found',
#   'fascin',
#   'develop',
#   'would',
#   'love',
#   'add',
#   'support',
#   'powerglov',
#   'hmd',
#   'final',
#   'one',
#   'major',
#   'disclaim',
#   'total',
#   'amateur',
#   'code',
#   'mean',
#   'support',
#   'code',
#   'kind',
#   'heart',
#   'pure',
#   'desper',
#   'provid',
#   'held',
#   'respons',
#   'anyth',
#   'good',
#   'bad',
#   'may',
#   'happen',
#   'use',
#   'code',
#   'use',
#   'risk',
#   'disclaim',
#   'cours',
#   'love',
#   'would',
#   'like',
#   'anyon',
#   'posit',
#   'contribut',
#   'critic',
#   'also',
#   'encourag',
#   'contact',
#   'anyon',
#   'hate',
#   'dev',
#   'null',
#   'anyon',
#   'want',
#   'let',
#   'live',
#   'know',
#   'write',
#   'thank',
#   'robert',
#   'robert',
#   'acsc',
#   'com'],
#  ['updat',
#   'locat',
#   'directori',
#   'public',
#   'virtual',
#   'world',
#   'sorri',
#   'robert',
#   'robert',
#   'acsc',
#   'com']]

# %%
DF = {}
N = len(processed_text)

for i in range(N):
    tokens = processed_text[i]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}


for i in DF:
    DF[i] = len(DF[i])

# %%
def doc_freq(word): 
    c = 0 
    try: 
        c = DF[word] 
    except: 
        pass 
    return c 

WORD = 'path'
print()

# %%
tf_idf = {} 
doc = 0
 
for i in range(N): 
     
    tokens = processed_text[i] 
     
    counter = Counter(tokens + processed_text[i]) 
    words_count = len(tokens + processed_text[i]) 
     
    for token in np.unique(tokens): 
         
        tf = counter[token]/words_count 
        df = doc_freq(token) 
        idf = np.log((N+1)/(df+1)) 
         
        tf_idf[doc, token] = tf*idf 
 
    doc += 1

# %%
def matching_score(k, query): 
    preprocessed_query = preprocess(query,True) 
    tokens = word_tokenize(str(preprocessed_query)) 
 
    print("Matching Score") 
    print("\nQuery:", query) 
    print("") 
    print(tokens) 
     
    query_weights = {}

    for key in tf_idf:
        if key[1] in tokens:
            try:
                query_weights[key[0]] += tf_idf[key] 
            except:
                query_weights[key[0]] = tf_idf[key] 
     
    query_weights = sorted(query_weights.items(), 
                           key=lambda x: x[1], 
                           reverse=True) 
 
    print("") 
     
    l = [] 
     
    for i in query_weights[:k]: 
        l.append(i[0]) 
     
    print(l) 
     
 
matching_score(2,  
              "I recently got a file describing a library")
# Out:
# No Header
# Matching Score
#
# Query: I recently got a file describing a library
#
# ['recent', 'got', 'file', 'describ', 'librari']
#
# [4, 51]
